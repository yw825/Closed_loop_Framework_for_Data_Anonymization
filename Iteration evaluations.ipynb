# %%
import pandas as pd
import numpy as np
import os
import glob
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel, wilcoxon, shapiro
from sklearn.model_selection import GridSearchCV
import gc
import itertools
from sklearn.utils import resample
import ast
import json
import re
import statsmodels.api as sm

import utils 
import model_train
from constants import *
import particle_swarm

# %load_ext autoreload
# %autoreload 2

# %%
results_df = pd.read_csv('/Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/Experiment results/V2/Iteration Tracking Info/DT_Anonymization_1.csv')

# %%
utils.plot_metric_trend_for_each_particle(results_df, 'Entropy-Loss', 'Avg entropy', smooth_method='moving_avg', window_size=5, y_range=None)

# %%
utils.plot_global_best_so_far(results_df, 'Entropy-Loss', 'Minimum Loss Function Value')

# %%
utils.plot_global_best_so_far(results_df, 'num_violated_clusters', 'Number of Violated Clusters')

# %%
utils.plot_global_best_so_far(results_df, 'num_violating_records_before_adjusting', 'Number of Violated Records')

# %%
utils.plot_global_best_so_far(results_df, 'num_total_violating_records_after_adjusting', 'Number of Violated Records')
