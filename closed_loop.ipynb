# %%
import pandas as pd
import numpy as np
import os
import glob
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel, wilcoxon, shapiro
from sklearn.model_selection import GridSearchCV
import gc
import itertools
from sklearn.utils import resample
import ast
import json
import re
from sklearn.base import clone
import copy

import utils 
import model_train
from constants import *
import particle_swarm


# %load_ext autoreload
# %autoreload 2

# %%
# List of file paths
df = pd.read_csv(path)
df
# Out:
#     checking_status  duration                  credit_history  \
# 0                <0         6  critical/other existing credit
# 1          0<=X<200        48                   existing paid
# 2       no checking        12  critical/other existing credit
# 3                <0        42                   existing paid
# 4                <0        24              delayed previously
# ..              ...       ...                             ...
# 995     no checking        12                   existing paid
# 996              <0        30                   existing paid
# 997     no checking        12                   existing paid
# 998              <0        45                   existing paid
# 999        0<=X<200        45  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 0               radio/tv           1169  no known savings         >=7
# 1               radio/tv           5951              <100      1<=X<4
# 2              education           2096              <100      4<=X<7
# 3    furniture/equipment           7882              <100      4<=X<7
# 4                new car           4870              <100      1<=X<4
# ..                   ...            ...               ...         ...
# 995  furniture/equipment           1736              <100      4<=X<7
# 996             used car           3857              <100      1<=X<4
# 997             radio/tv            804              <100         >=7
# 998             radio/tv           1845              <100      1<=X<4
# 999             used car           4576        100<=X<500  unemployed
#
#      installment_commitment     personal_status other_parties  ...  \
# 0                         4         male single          none  ...
# 1                         2  female div/dep/mar          none  ...
# 2                         2         male single          none  ...
# 3                         2         male single     guarantor  ...
# 4                         3         male single          none  ...
# ..                      ...                 ...           ...  ...
# 995                       3  female div/dep/mar          none  ...
# 996                       4        male div/sep          none  ...
# 997                       4         male single          none  ...
# 998                       4         male single          none  ...
# 999                       3         male single          none  ...
#
#      property_magnitude age  other_payment_plans   housing existing_credits  \
# 0           real estate  67                 none       own                2
# 1           real estate  22                 none       own                1
# 2           real estate  49                 none       own                1
# 3        life insurance  45                 none  for free                1
# 4     no known property  53                 none  for free                2
# ..                  ...  ..                  ...       ...              ...
# 995         real estate  31                 none       own                1
# 996      life insurance  40                 none       own                1
# 997                 car  38                 none       own                1
# 998   no known property  23                 none  for free                1
# 999                 car  27                 none       own                1
#
#                            job num_dependents  own_telephone foreign_worker  \
# 0                      skilled              1            yes            yes
# 1                      skilled              1           none            yes
# 2           unskilled resident              2           none            yes
# 3                      skilled              2           none            yes
# 4                      skilled              2           none            yes
# ..                         ...            ...            ...            ...
# 995         unskilled resident              1           none            yes
# 996  high qualif/self emp/mgmt              1            yes            yes
# 997                    skilled              1           none            yes
# 998                    skilled              1            yes            yes
# 999                    skilled              1           none            yes
#
#     credit_risk
# 0          good
# 1           bad
# 2          good
# 3          good
# 4           bad
# ..          ...
# 995        good
# 996        good
# 997        good
# 998         bad
# 999        good
#
# [1000 rows x 21 columns]

# %%
df = utils.data_prep(df)

bounds = utils.get_nqi_bounds(df, NQIs)
levels = utils.get_cqi_levels(df, CQIs)
nqi_means = df[NQIs].mean()

# %%
# Define a list of ML models
models = [
    ("DT", DecisionTreeClassifier(criterion='entropy', random_state=42)),
    # ("LR", LogisticRegression(solver='lbfgs', max_iter=100, random_state=42, n_jobs=-1)),
    # ("NB", GaussianNB()),
    # ("NN", MLPClassifier(random_state=42)),
    # ("RF", RandomForestClassifier(criterion='entropy', random_state=42)),
    # ("SVM", LinearSVC(random_state=42))   
]

# %%
# Define the dictionary with all parameter values
parameters_dic = {'gamma': [1],
                  'k': [20],
                  'n_cluster': [3],
                  'initial_violation_threshold': [10],
                  'violation_decay_rate': [0.5],
                  'penalty_weight': [1]
                  }

# Generate all combinations of parameters using itertools.product
param_combinations = list(itertools.product(*parameters_dic.values()))

# %%
results = particle_swarm.run_particle_swarm_experiment(
    df=df, 
    models=models, 
    param_combinations=param_combinations, 
    NQIs=NQIs, 
    CQIs=CQIs, 
    n_population=20,
    maxIter=20,
    n_bootstrap=2,
    bounds=bounds, 
    levels=levels, 
    nqi_means=nqi_means, 
    filedirectory='/Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/Experiment results/V2/Anonymized Data'
)
# Out:
# Running with k = 20, n_cluster = 3,  initial_violation_threshold = 10, violation_decay_rate = 0.5, penalty_weight = 1
# Training model: DT
# Iteration: 0
# In iteration_info, Iteration 0 Particel 0 results: [11.53396908 10.09222295]
# In iteration_info, Iteration 0 Particel 1 results: [11.89440562  9.91200468]
# In iteration_info, Iteration 0 Particel 2 results: [12.07462389 10.45265948]
# In iteration_info, Iteration 0 Particel 3 results: [12.25484215  9.19113161]
# In iteration_info, Iteration 0 Particel 4 results: [13.15593349 12.61527869]
# In iteration_info, Iteration 0 Particel 5 results: [11.53396908 11.35375082]
# In iteration_info, Iteration 0 Particel 6 results: [12.43506042 10.63287775]
# In iteration_info, Iteration 0 Particel 7 results: [11.17353255 10.99331428]
# In iteration_info, Iteration 0 Particel 8 results: [10.09222295  9.91200468]
# In iteration_info, Iteration 0 Particel 9 results: [10.09222295  8.83069508]
# In iteration_info, Iteration 0 Particel 10 results: [11.71418735  9.01091335]
# In iteration_info, Iteration 0 Particel 11 results: [11.17353255 10.81309602]
# In iteration_info, Iteration 0 Particel 12 results: [10.99331428  9.37134988]
# In iteration_info, Iteration 0 Particel 13 results: [10.45265948  9.55156815]
# In iteration_info, Iteration 0 Particel 14 results: [11.17353255 11.53396908]
# In iteration_info, Iteration 0 Particel 15 results: [11.71418735 12.07462389]
# In iteration_info, Iteration 0 Particel 16 results: [13.51637002 12.25484215]
# In iteration_info, Iteration 0 Particel 17 results: [10.81309602 11.89440562]
# In iteration_info, Iteration 0 Particel 18 results: [10.09222295 11.53396908]
# In iteration_info, Iteration 0 Particel 19 results: [9.91200468 9.73178642]
# In results, Iteration 0:
# Particle 0: Entropy-Loss = [11.53396908 10.09222295]
# Particle 1: Entropy-Loss = [11.89440562  9.91200468]
# Particle 2: Entropy-Loss = [12.07462389 10.45265948]
# Particle 3: Entropy-Loss = [12.25484215  9.19113161]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [11.53396908 11.35375082]
# Particle 6: Entropy-Loss = [12.43506042 10.63287775]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [11.17353255 11.53396908]
# Particle 15: Entropy-Loss = [11.71418735 12.07462389]
# Particle 16: Entropy-Loss = [13.51637002 12.25484215]
# Particle 17: Entropy-Loss = [10.81309602 11.89440562]
# Particle 18: Entropy-Loss = [10.09222295 11.53396908]
# Particle 19: Entropy-Loss = [9.91200468 9.73178642]
# Iteration: 1
# In iteration_info, Iteration 1 Particel 0 results: [13.87680655 10.09222295]
# In iteration_info, Iteration 1 Particel 1 results: [11.53396908 13.33615175]
# In iteration_info, Iteration 1 Particel 2 results: [12.25484215 11.35375082]
# /Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/particle_swarm.py:311: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   particle_numeric[mask_low, col_idx] = column_means[col_idx]
# /Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/particle_swarm.py:312: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   particle_numeric[mask_high, col_idx] = column_means[col_idx]
# In iteration_info, Iteration 1 Particel 3 results: [13.87680655 12.07462389]
# In iteration_info, Iteration 1 Particel 4 results: [13.15593349 12.61527869]
# In iteration_info, Iteration 1 Particel 5 results: [10.81309602 13.87680655]
# In iteration_info, Iteration 1 Particel 6 results: [12.43506042 10.81309602]
# In iteration_info, Iteration 1 Particel 7 results: [11.17353255 10.99331428]
# In iteration_info, Iteration 1 Particel 8 results: [10.09222295  9.91200468]
# In iteration_info, Iteration 1 Particel 9 results: [10.09222295  8.83069508]
# In iteration_info, Iteration 1 Particel 10 results: [11.71418735  9.01091335]
# In iteration_info, Iteration 1 Particel 11 results: [11.17353255 10.81309602]
# In iteration_info, Iteration 1 Particel 12 results: [10.99331428  9.37134988]
# In iteration_info, Iteration 1 Particel 13 results: [10.45265948  9.55156815]
# In iteration_info, Iteration 1 Particel 14 results: [10.99331428 11.17353255]
# In iteration_info, Iteration 1 Particel 15 results: [9.55156815 9.37134988]
# In iteration_info, Iteration 1 Particel 16 results: [11.35375082 10.27244122]
# In iteration_info, Iteration 1 Particel 17 results: [13.69658829 10.63287775]
# In iteration_info, Iteration 1 Particel 18 results: [ 9.91200468 10.27244122]
# In iteration_info, Iteration 1 Particel 19 results: [9.91200468 9.73178642]
# In results, Iteration 0:
# Particle 0: Entropy-Loss = [11.53396908 10.09222295]
# Particle 1: Entropy-Loss = [11.89440562  9.91200468]
# Particle 2: Entropy-Loss = [12.07462389 10.45265948]
# Particle 3: Entropy-Loss = [12.25484215  9.19113161]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [11.53396908 11.35375082]
# Particle 6: Entropy-Loss = [12.43506042 10.63287775]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [11.17353255 11.53396908]
# Particle 15: Entropy-Loss = [11.71418735 12.07462389]
# Particle 16: Entropy-Loss = [13.51637002 12.25484215]
# Particle 17: Entropy-Loss = [10.81309602 11.89440562]
# Particle 18: Entropy-Loss = [10.09222295 11.53396908]
# Particle 19: Entropy-Loss = [9.91200468 9.73178642]
# In results, Iteration 1:
# Particle 0: Entropy-Loss = [13.87680655 10.09222295]
# Particle 1: Entropy-Loss = [11.53396908 13.33615175]
# Particle 2: Entropy-Loss = [12.25484215 11.35375082]
# Particle 3: Entropy-Loss = [13.87680655 12.07462389]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [10.81309602 13.87680655]
# Particle 6: Entropy-Loss = [12.43506042 10.81309602]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [10.99331428 11.17353255]
# Particle 15: Entropy-Loss = [9.55156815 9.37134988]
# Particle 16: Entropy-Loss = [11.35375082 10.27244122]
# Particle 17: Entropy-Loss = [13.69658829 10.63287775]
# Particle 18: Entropy-Loss = [ 9.91200468 10.27244122]
# Particle 19: Entropy-Loss = [9.91200468 9.73178642]
# Iteration: 2
# In iteration_info, Iteration 2 Particel 0 results: [12.07462389 10.81309602]
# In iteration_info, Iteration 2 Particel 1 results: [11.53396908 13.33615175]
# In iteration_info, Iteration 2 Particel 2 results: [12.25484215 11.35375082]
# In iteration_info, Iteration 2 Particel 3 results: [13.87680655 12.07462389]
# In iteration_info, Iteration 2 Particel 4 results: [13.15593349 12.61527869]
# In iteration_info, Iteration 2 Particel 5 results: [10.81309602 13.87680655]
# In iteration_info, Iteration 2 Particel 6 results: [12.07462389 10.63287775]
# /Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/particle_swarm.py:311: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   particle_numeric[mask_low, col_idx] = column_means[col_idx]
# /Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/particle_swarm.py:312: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   particle_numeric[mask_high, col_idx] = column_means[col_idx]
# In iteration_info, Iteration 2 Particel 7 results: [11.17353255 10.99331428]
# In iteration_info, Iteration 2 Particel 8 results: [10.09222295  9.91200468]
# In iteration_info, Iteration 2 Particel 9 results: [10.09222295  8.83069508]
# In iteration_info, Iteration 2 Particel 10 results: [11.71418735  9.01091335]
# In iteration_info, Iteration 2 Particel 11 results: [11.17353255 10.81309602]
# In iteration_info, Iteration 2 Particel 12 results: [10.99331428  9.37134988]
# In iteration_info, Iteration 2 Particel 13 results: [10.45265948  9.55156815]
# In iteration_info, Iteration 2 Particel 14 results: [11.35375082 10.27244122]
# In iteration_info, Iteration 2 Particel 15 results: [9.55156815 9.37134988]
# In iteration_info, Iteration 2 Particel 16 results: [11.35375082 10.27244122]
# In iteration_info, Iteration 2 Particel 17 results: [10.09222295 11.17353255]
# In iteration_info, Iteration 2 Particel 18 results: [ 9.91200468 10.27244122]
# In iteration_info, Iteration 2 Particel 19 results: [13.15593349 12.07462389]
# In results, Iteration 0:
# Particle 0: Entropy-Loss = [11.53396908 10.09222295]
# Particle 1: Entropy-Loss = [11.89440562  9.91200468]
# Particle 2: Entropy-Loss = [12.07462389 10.45265948]
# Particle 3: Entropy-Loss = [12.25484215  9.19113161]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [11.53396908 11.35375082]
# Particle 6: Entropy-Loss = [12.43506042 10.63287775]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [11.17353255 11.53396908]
# Particle 15: Entropy-Loss = [11.71418735 12.07462389]
# Particle 16: Entropy-Loss = [13.51637002 12.25484215]
# Particle 17: Entropy-Loss = [10.81309602 11.89440562]
# Particle 18: Entropy-Loss = [10.09222295 11.53396908]
# Particle 19: Entropy-Loss = [9.91200468 9.73178642]
# In results, Iteration 1:
# Particle 0: Entropy-Loss = [13.87680655 10.09222295]
# Particle 1: Entropy-Loss = [11.53396908 13.33615175]
# Particle 2: Entropy-Loss = [12.25484215 11.35375082]
# Particle 3: Entropy-Loss = [13.87680655 12.07462389]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [10.81309602 13.87680655]
# Particle 6: Entropy-Loss = [12.43506042 10.81309602]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [10.99331428 11.17353255]
# Particle 15: Entropy-Loss = [9.55156815 9.37134988]
# Particle 16: Entropy-Loss = [11.35375082 10.27244122]
# Particle 17: Entropy-Loss = [13.69658829 10.63287775]
# Particle 18: Entropy-Loss = [ 9.91200468 10.27244122]
# Particle 19: Entropy-Loss = [9.91200468 9.73178642]
# In results, Iteration 2:
# Particle 0: Entropy-Loss = [12.07462389 10.81309602]
# Particle 1: Entropy-Loss = [11.53396908 13.33615175]
# Particle 2: Entropy-Loss = [12.25484215 11.35375082]
# Particle 3: Entropy-Loss = [13.87680655 12.07462389]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [10.81309602 13.87680655]
# Particle 6: Entropy-Loss = [12.07462389 10.63287775]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [11.35375082 10.27244122]
# Particle 15: Entropy-Loss = [9.55156815 9.37134988]
# Particle 16: Entropy-Loss = [11.35375082 10.27244122]
# Particle 17: Entropy-Loss = [10.09222295 11.17353255]
# Particle 18: Entropy-Loss = [ 9.91200468 10.27244122]
# Particle 19: Entropy-Loss = [13.15593349 12.07462389]
# Iteration: 3
# In iteration_info, Iteration 3 Particel 0 results: [13.15593349 11.35375082]
# In iteration_info, Iteration 3 Particel 1 results: [11.53396908 13.33615175]
# /Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/particle_swarm.py:311: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   particle_numeric[mask_low, col_idx] = column_means[col_idx]
# /Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/particle_swarm.py:312: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   particle_numeric[mask_high, col_idx] = column_means[col_idx]
# In iteration_info, Iteration 3 Particel 2 results: [11.89440562 10.99331428]
# In iteration_info, Iteration 3 Particel 3 results: [13.87680655 12.07462389]
# In iteration_info, Iteration 3 Particel 4 results: [11.17353255  9.73178642]
# In iteration_info, Iteration 3 Particel 5 results: [14.05702482 10.81309602]
# In iteration_info, Iteration 3 Particel 6 results: [12.07462389 11.17353255]
# In iteration_info, Iteration 3 Particel 7 results: [11.17353255 10.99331428]
# In iteration_info, Iteration 3 Particel 8 results: [10.09222295  9.91200468]
# In iteration_info, Iteration 3 Particel 9 results: [ 9.37134988 10.99331428]
# In iteration_info, Iteration 3 Particel 10 results: [11.71418735  9.01091335]
# In iteration_info, Iteration 3 Particel 11 results: [11.17353255 10.81309602]
# In iteration_info, Iteration 3 Particel 12 results: [12.61527869 10.45265948]
# In iteration_info, Iteration 3 Particel 13 results: [ 8.29004028 12.61527869]
# In iteration_info, Iteration 3 Particel 14 results: [10.63287775  9.19113161]
# In iteration_info, Iteration 3 Particel 15 results: [12.25484215  9.19113161]
# In iteration_info, Iteration 3 Particel 16 results: [11.35375082 10.27244122]
# In iteration_info, Iteration 3 Particel 17 results: [10.09222295 11.17353255]
# In iteration_info, Iteration 3 Particel 18 results: [11.71418735  8.47025855]
# In iteration_info, Iteration 3 Particel 19 results: [13.15593349 12.07462389]
# In results, Iteration 0:
# Particle 0: Entropy-Loss = [11.53396908 10.09222295]
# Particle 1: Entropy-Loss = [11.89440562  9.91200468]
# Particle 2: Entropy-Loss = [12.07462389 10.45265948]
# Particle 3: Entropy-Loss = [12.25484215  9.19113161]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [11.53396908 11.35375082]
# Particle 6: Entropy-Loss = [12.43506042 10.63287775]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [11.17353255 11.53396908]
# Particle 15: Entropy-Loss = [11.71418735 12.07462389]
# Particle 16: Entropy-Loss = [13.51637002 12.25484215]
# Particle 17: Entropy-Loss = [10.81309602 11.89440562]
# Particle 18: Entropy-Loss = [10.09222295 11.53396908]
# Particle 19: Entropy-Loss = [9.91200468 9.73178642]
# In results, Iteration 1:
# Particle 0: Entropy-Loss = [13.87680655 10.09222295]
# Particle 1: Entropy-Loss = [11.53396908 13.33615175]
# Particle 2: Entropy-Loss = [12.25484215 11.35375082]
# Particle 3: Entropy-Loss = [13.87680655 12.07462389]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [10.81309602 13.87680655]
# Particle 6: Entropy-Loss = [12.43506042 10.81309602]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [10.99331428 11.17353255]
# Particle 15: Entropy-Loss = [9.55156815 9.37134988]
# Particle 16: Entropy-Loss = [11.35375082 10.27244122]
# Particle 17: Entropy-Loss = [13.69658829 10.63287775]
# Particle 18: Entropy-Loss = [ 9.91200468 10.27244122]
# Particle 19: Entropy-Loss = [9.91200468 9.73178642]
# In results, Iteration 2:
# Particle 0: Entropy-Loss = [12.07462389 10.81309602]
# Particle 1: Entropy-Loss = [11.53396908 13.33615175]
# Particle 2: Entropy-Loss = [12.25484215 11.35375082]
# Particle 3: Entropy-Loss = [13.87680655 12.07462389]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [10.81309602 13.87680655]
# Particle 6: Entropy-Loss = [12.07462389 10.63287775]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [11.35375082 10.27244122]
# Particle 15: Entropy-Loss = [9.55156815 9.37134988]
# Particle 16: Entropy-Loss = [11.35375082 10.27244122]
# Particle 17: Entropy-Loss = [10.09222295 11.17353255]
# Particle 18: Entropy-Loss = [ 9.91200468 10.27244122]
# Particle 19: Entropy-Loss = [13.15593349 12.07462389]
# In results, Iteration 3:
# Particle 0: Entropy-Loss = [13.15593349 11.35375082]
# Particle 1: Entropy-Loss = [11.53396908 13.33615175]
# Particle 2: Entropy-Loss = [11.89440562 10.99331428]
# Particle 3: Entropy-Loss = [13.87680655 12.07462389]
# Particle 4: Entropy-Loss = [11.17353255  9.73178642]
# Particle 5: Entropy-Loss = [14.05702482 10.81309602]
# Particle 6: Entropy-Loss = [12.07462389 11.17353255]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [ 9.37134988 10.99331428]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [12.61527869 10.45265948]
# Particle 13: Entropy-Loss = [ 8.29004028 12.61527869]
# Particle 14: Entropy-Loss = [10.63287775  9.19113161]
# Particle 15: Entropy-Loss = [12.25484215  9.19113161]
# Particle 16: Entropy-Loss = [11.35375082 10.27244122]
# Particle 17: Entropy-Loss = [10.09222295 11.17353255]
# Particle 18: Entropy-Loss = [11.71418735  8.47025855]
# Particle 19: Entropy-Loss = [13.15593349 12.07462389]
# Iteration: 4
# In iteration_info, Iteration 4 Particel 0 results: [11.71418735 12.43506042]
# In iteration_info, Iteration 4 Particel 1 results: [12.61527869 10.45265948]
# In iteration_info, Iteration 4 Particel 2 results: [12.61527869 12.61527869]
# In iteration_info, Iteration 4 Particel 3 results: [11.71418735 11.53396908]
# /Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/particle_swarm.py:311: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   particle_numeric[mask_low, col_idx] = column_means[col_idx]
# /Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/particle_swarm.py:312: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   particle_numeric[mask_high, col_idx] = column_means[col_idx]
# In iteration_info, Iteration 4 Particel 4 results: [11.17353255  9.73178642]
# In iteration_info, Iteration 4 Particel 5 results: [10.99331428 10.09222295]
# In iteration_info, Iteration 4 Particel 6 results: [12.07462389 11.17353255]
# In iteration_info, Iteration 4 Particel 7 results: [ 9.37134988 10.81309602]
# In iteration_info, Iteration 4 Particel 8 results: [ 9.73178642 11.71418735]
# In iteration_info, Iteration 4 Particel 9 results: [11.17353255 12.25484215]
# In iteration_info, Iteration 4 Particel 10 results: [11.71418735 10.81309602]
# In iteration_info, Iteration 4 Particel 11 results: [12.07462389 12.07462389]
# In iteration_info, Iteration 4 Particel 12 results: [10.99331428 11.53396908]
# In iteration_info, Iteration 4 Particel 13 results: [10.99331428 11.71418735]
# In iteration_info, Iteration 4 Particel 14 results: [11.35375082  9.19113161]
# In iteration_info, Iteration 4 Particel 15 results: [12.25484215  9.19113161]
# In iteration_info, Iteration 4 Particel 16 results: [12.43506042 10.09222295]
# In iteration_info, Iteration 4 Particel 17 results: [10.81309602 10.45265948]
# In iteration_info, Iteration 4 Particel 18 results: [11.17353255 14.05702482]
# In iteration_info, Iteration 4 Particel 19 results: [13.15593349 12.07462389]
# In results, Iteration 0:
# Particle 0: Entropy-Loss = [11.53396908 10.09222295]
# Particle 1: Entropy-Loss = [11.89440562  9.91200468]
# Particle 2: Entropy-Loss = [12.07462389 10.45265948]
# Particle 3: Entropy-Loss = [12.25484215  9.19113161]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [11.53396908 11.35375082]
# Particle 6: Entropy-Loss = [12.43506042 10.63287775]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [11.17353255 11.53396908]
# Particle 15: Entropy-Loss = [11.71418735 12.07462389]
# Particle 16: Entropy-Loss = [13.51637002 12.25484215]
# Particle 17: Entropy-Loss = [10.81309602 11.89440562]
# Particle 18: Entropy-Loss = [10.09222295 11.53396908]
# Particle 19: Entropy-Loss = [9.91200468 9.73178642]
# In results, Iteration 1:
# Particle 0: Entropy-Loss = [13.87680655 10.09222295]
# Particle 1: Entropy-Loss = [11.53396908 13.33615175]
# Particle 2: Entropy-Loss = [12.25484215 11.35375082]
# Particle 3: Entropy-Loss = [13.87680655 12.07462389]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [10.81309602 13.87680655]
# Particle 6: Entropy-Loss = [12.43506042 10.81309602]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [10.99331428 11.17353255]
# Particle 15: Entropy-Loss = [9.55156815 9.37134988]
# Particle 16: Entropy-Loss = [11.35375082 10.27244122]
# Particle 17: Entropy-Loss = [13.69658829 10.63287775]
# Particle 18: Entropy-Loss = [ 9.91200468 10.27244122]
# Particle 19: Entropy-Loss = [9.91200468 9.73178642]
# In results, Iteration 2:
# Particle 0: Entropy-Loss = [12.07462389 10.81309602]
# Particle 1: Entropy-Loss = [11.53396908 13.33615175]
# Particle 2: Entropy-Loss = [12.25484215 11.35375082]
# Particle 3: Entropy-Loss = [13.87680655 12.07462389]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [10.81309602 13.87680655]
# Particle 6: Entropy-Loss = [12.07462389 10.63287775]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [11.35375082 10.27244122]
# Particle 15: Entropy-Loss = [9.55156815 9.37134988]
# Particle 16: Entropy-Loss = [11.35375082 10.27244122]
# Particle 17: Entropy-Loss = [10.09222295 11.17353255]
# Particle 18: Entropy-Loss = [ 9.91200468 10.27244122]
# Particle 19: Entropy-Loss = [13.15593349 12.07462389]
# In results, Iteration 3:
# Particle 0: Entropy-Loss = [13.15593349 11.35375082]
# Particle 1: Entropy-Loss = [11.53396908 13.33615175]
# Particle 2: Entropy-Loss = [11.89440562 10.99331428]
# Particle 3: Entropy-Loss = [13.87680655 12.07462389]
# Particle 4: Entropy-Loss = [11.17353255  9.73178642]
# Particle 5: Entropy-Loss = [14.05702482 10.81309602]
# Particle 6: Entropy-Loss = [12.07462389 11.17353255]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [ 9.37134988 10.99331428]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [12.61527869 10.45265948]
# Particle 13: Entropy-Loss = [ 8.29004028 12.61527869]
# Particle 14: Entropy-Loss = [10.63287775  9.19113161]
# Particle 15: Entropy-Loss = [12.25484215  9.19113161]
# Particle 16: Entropy-Loss = [11.35375082 10.27244122]
# Particle 17: Entropy-Loss = [10.09222295 11.17353255]
# Particle 18: Entropy-Loss = [11.71418735  8.47025855]
# Particle 19: Entropy-Loss = [13.15593349 12.07462389]
# In results, Iteration 4:
# Particle 0: Entropy-Loss = [11.71418735 12.43506042]
# Particle 1: Entropy-Loss = [12.61527869 10.45265948]
# Particle 2: Entropy-Loss = [12.61527869 12.61527869]
# Particle 3: Entropy-Loss = [11.71418735 11.53396908]
# Particle 4: Entropy-Loss = [11.17353255  9.73178642]
# Particle 5: Entropy-Loss = [10.99331428 10.09222295]
# Particle 6: Entropy-Loss = [12.07462389 11.17353255]
# Particle 7: Entropy-Loss = [ 9.37134988 10.81309602]
# Particle 8: Entropy-Loss = [ 9.73178642 11.71418735]
# Particle 9: Entropy-Loss = [11.17353255 12.25484215]
# Particle 10: Entropy-Loss = [11.71418735 10.81309602]
# Particle 11: Entropy-Loss = [12.07462389 12.07462389]
# Particle 12: Entropy-Loss = [10.99331428 11.53396908]
# Particle 13: Entropy-Loss = [10.99331428 11.71418735]
# Particle 14: Entropy-Loss = [11.35375082  9.19113161]
# Particle 15: Entropy-Loss = [12.25484215  9.19113161]
# Particle 16: Entropy-Loss = [12.43506042 10.09222295]
# Particle 17: Entropy-Loss = [10.81309602 10.45265948]
# Particle 18: Entropy-Loss = [11.17353255 14.05702482]
# Particle 19: Entropy-Loss = [13.15593349 12.07462389]
# Iteration: 5
# /Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/particle_swarm.py:311: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   particle_numeric[mask_low, col_idx] = column_means[col_idx]
# /Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/particle_swarm.py:312: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   particle_numeric[mask_high, col_idx] = column_means[col_idx]
# In iteration_info, Iteration 5 Particel 0 results: [10.99331428 10.81309602]
# In iteration_info, Iteration 5 Particel 1 results: [12.61527869 10.45265948]
# In iteration_info, Iteration 5 Particel 2 results: [12.61527869 12.61527869]
# In iteration_info, Iteration 5 Particel 3 results: [12.79549695  9.91200468]
# In iteration_info, Iteration 5 Particel 4 results: [11.17353255  9.73178642]
# In iteration_info, Iteration 5 Particel 5 results: [10.45265948 11.71418735]
# In iteration_info, Iteration 5 Particel 6 results: [12.07462389 11.17353255]
# In iteration_info, Iteration 5 Particel 7 results: [ 9.37134988 10.81309602]
# In iteration_info, Iteration 5 Particel 8 results: [10.99331428 10.63287775]
# In iteration_info, Iteration 5 Particel 9 results: [11.53396908 11.53396908]
# In iteration_info, Iteration 5 Particel 10 results: [11.17353255 12.43506042]
# In iteration_info, Iteration 5 Particel 11 results: [12.07462389 12.07462389]
# In iteration_info, Iteration 5 Particel 12 results: [ 7.74938548 11.53396908]
# In iteration_info, Iteration 5 Particel 13 results: [11.71418735 12.25484215]
# In iteration_info, Iteration 5 Particel 14 results: [11.17353255 11.17353255]
# In iteration_info, Iteration 5 Particel 15 results: [12.25484215  9.19113161]
# In iteration_info, Iteration 5 Particel 16 results: [12.43506042 10.09222295]
# In iteration_info, Iteration 5 Particel 17 results: [10.81309602 10.45265948]
# In iteration_info, Iteration 5 Particel 18 results: [12.79549695 11.71418735]
# In iteration_info, Iteration 5 Particel 19 results: [11.35375082 10.81309602]
# In results, Iteration 0:
# Particle 0: Entropy-Loss = [11.53396908 10.09222295]
# Particle 1: Entropy-Loss = [11.89440562  9.91200468]
# Particle 2: Entropy-Loss = [12.07462389 10.45265948]
# Particle 3: Entropy-Loss = [12.25484215  9.19113161]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [11.53396908 11.35375082]
# Particle 6: Entropy-Loss = [12.43506042 10.63287775]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [11.17353255 11.53396908]
# Particle 15: Entropy-Loss = [11.71418735 12.07462389]
# Particle 16: Entropy-Loss = [13.51637002 12.25484215]
# Particle 17: Entropy-Loss = [10.81309602 11.89440562]
# Particle 18: Entropy-Loss = [10.09222295 11.53396908]
# Particle 19: Entropy-Loss = [9.91200468 9.73178642]
# In results, Iteration 1:
# Particle 0: Entropy-Loss = [13.87680655 10.09222295]
# Particle 1: Entropy-Loss = [11.53396908 13.33615175]
# Particle 2: Entropy-Loss = [12.25484215 11.35375082]
# Particle 3: Entropy-Loss = [13.87680655 12.07462389]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [10.81309602 13.87680655]
# Particle 6: Entropy-Loss = [12.43506042 10.81309602]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [10.99331428 11.17353255]
# Particle 15: Entropy-Loss = [9.55156815 9.37134988]
# Particle 16: Entropy-Loss = [11.35375082 10.27244122]
# Particle 17: Entropy-Loss = [13.69658829 10.63287775]
# Particle 18: Entropy-Loss = [ 9.91200468 10.27244122]
# Particle 19: Entropy-Loss = [9.91200468 9.73178642]
# In results, Iteration 2:
# Particle 0: Entropy-Loss = [12.07462389 10.81309602]
# Particle 1: Entropy-Loss = [11.53396908 13.33615175]
# Particle 2: Entropy-Loss = [12.25484215 11.35375082]
# Particle 3: Entropy-Loss = [13.87680655 12.07462389]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [10.81309602 13.87680655]
# Particle 6: Entropy-Loss = [12.07462389 10.63287775]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [11.35375082 10.27244122]
# Particle 15: Entropy-Loss = [9.55156815 9.37134988]
# Particle 16: Entropy-Loss = [11.35375082 10.27244122]
# Particle 17: Entropy-Loss = [10.09222295 11.17353255]
# Particle 18: Entropy-Loss = [ 9.91200468 10.27244122]
# Particle 19: Entropy-Loss = [13.15593349 12.07462389]
# In results, Iteration 3:
# Particle 0: Entropy-Loss = [13.15593349 11.35375082]
# Particle 1: Entropy-Loss = [11.53396908 13.33615175]
# Particle 2: Entropy-Loss = [11.89440562 10.99331428]
# Particle 3: Entropy-Loss = [13.87680655 12.07462389]
# Particle 4: Entropy-Loss = [11.17353255  9.73178642]
# Particle 5: Entropy-Loss = [14.05702482 10.81309602]
# Particle 6: Entropy-Loss = [12.07462389 11.17353255]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [ 9.37134988 10.99331428]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [12.61527869 10.45265948]
# Particle 13: Entropy-Loss = [ 8.29004028 12.61527869]
# Particle 14: Entropy-Loss = [10.63287775  9.19113161]
# Particle 15: Entropy-Loss = [12.25484215  9.19113161]
# Particle 16: Entropy-Loss = [11.35375082 10.27244122]
# Particle 17: Entropy-Loss = [10.09222295 11.17353255]
# Particle 18: Entropy-Loss = [11.71418735  8.47025855]
# Particle 19: Entropy-Loss = [13.15593349 12.07462389]
# In results, Iteration 4:
# Particle 0: Entropy-Loss = [11.71418735 12.43506042]
# Particle 1: Entropy-Loss = [12.61527869 10.45265948]
# Particle 2: Entropy-Loss = [12.61527869 12.61527869]
# Particle 3: Entropy-Loss = [11.71418735 11.53396908]
# Particle 4: Entropy-Loss = [11.17353255  9.73178642]
# Particle 5: Entropy-Loss = [10.99331428 10.09222295]
# Particle 6: Entropy-Loss = [12.07462389 11.17353255]
# Particle 7: Entropy-Loss = [ 9.37134988 10.81309602]
# Particle 8: Entropy-Loss = [ 9.73178642 11.71418735]
# Particle 9: Entropy-Loss = [11.17353255 12.25484215]
# Particle 10: Entropy-Loss = [11.71418735 10.81309602]
# Particle 11: Entropy-Loss = [12.07462389 12.07462389]
# Particle 12: Entropy-Loss = [10.99331428 11.53396908]
# Particle 13: Entropy-Loss = [10.99331428 11.71418735]
# Particle 14: Entropy-Loss = [11.35375082  9.19113161]
# Particle 15: Entropy-Loss = [12.25484215  9.19113161]
# Particle 16: Entropy-Loss = [12.43506042 10.09222295]
# Particle 17: Entropy-Loss = [10.81309602 10.45265948]
# Particle 18: Entropy-Loss = [11.17353255 14.05702482]
# Particle 19: Entropy-Loss = [13.15593349 12.07462389]
# In results, Iteration 5:
# Particle 0: Entropy-Loss = [10.99331428 10.81309602]
# Particle 1: Entropy-Loss = [12.61527869 10.45265948]
# Particle 2: Entropy-Loss = [12.61527869 12.61527869]
# Particle 3: Entropy-Loss = [12.79549695  9.91200468]
# Particle 4: Entropy-Loss = [11.17353255  9.73178642]
# Particle 5: Entropy-Loss = [10.45265948 11.71418735]
# Particle 6: Entropy-Loss = [12.07462389 11.17353255]
# Particle 7: Entropy-Loss = [ 9.37134988 10.81309602]
# Particle 8: Entropy-Loss = [10.99331428 10.63287775]
# Particle 9: Entropy-Loss = [11.53396908 11.53396908]
# Particle 10: Entropy-Loss = [11.17353255 12.43506042]
# Particle 11: Entropy-Loss = [12.07462389 12.07462389]
# Particle 12: Entropy-Loss = [ 7.74938548 11.53396908]
# Particle 13: Entropy-Loss = [11.71418735 12.25484215]
# Particle 14: Entropy-Loss = [11.17353255 11.17353255]
# Particle 15: Entropy-Loss = [12.25484215  9.19113161]
# Particle 16: Entropy-Loss = [12.43506042 10.09222295]
# Particle 17: Entropy-Loss = [10.81309602 10.45265948]
# Particle 18: Entropy-Loss = [12.79549695 11.71418735]
# Particle 19: Entropy-Loss = [11.35375082 10.81309602]
# Iteration: 6
# In iteration_info, Iteration 6 Particel 0 results: [13.15593349 11.71418735]
# In iteration_info, Iteration 6 Particel 1 results: [12.25484215 11.71418735]
# In iteration_info, Iteration 6 Particel 2 results: [11.53396908 10.45265948]
# /Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/particle_swarm.py:311: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   particle_numeric[mask_low, col_idx] = column_means[col_idx]
# /Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/particle_swarm.py:312: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   particle_numeric[mask_high, col_idx] = column_means[col_idx]
# In iteration_info, Iteration 6 Particel 3 results: [10.63287775 10.99331428]
# In iteration_info, Iteration 6 Particel 4 results: [ 9.91200468 10.63287775]
# In iteration_info, Iteration 6 Particel 5 results: [12.25484215  9.19113161]
# In iteration_info, Iteration 6 Particel 6 results: [12.07462389 11.17353255]
# In iteration_info, Iteration 6 Particel 7 results: [11.71418735  9.73178642]
# In iteration_info, Iteration 6 Particel 8 results: [12.07462389 12.25484215]
# In iteration_info, Iteration 6 Particel 9 results: [12.07462389 10.81309602]
# In iteration_info, Iteration 6 Particel 10 results: [11.17353255 12.43506042]
# In iteration_info, Iteration 6 Particel 11 results: [10.27244122 10.27244122]
# In iteration_info, Iteration 6 Particel 12 results: [12.07462389 12.43506042]
# In iteration_info, Iteration 6 Particel 13 results: [11.71418735 11.89440562]
# In iteration_info, Iteration 6 Particel 14 results: [ 9.73178642 10.27244122]
# In iteration_info, Iteration 6 Particel 15 results: [12.25484215  9.19113161]
# In iteration_info, Iteration 6 Particel 16 results: [11.35375082 11.89440562]
# In iteration_info, Iteration 6 Particel 17 results: [10.45265948 10.63287775]
# In iteration_info, Iteration 6 Particel 18 results: [10.63287775 12.97571522]
# In iteration_info, Iteration 6 Particel 19 results: [12.43506042 11.35375082]
# In results, Iteration 0:
# Particle 0: Entropy-Loss = [11.53396908 10.09222295]
# Particle 1: Entropy-Loss = [11.89440562  9.91200468]
# Particle 2: Entropy-Loss = [12.07462389 10.45265948]
# Particle 3: Entropy-Loss = [12.25484215  9.19113161]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [11.53396908 11.35375082]
# Particle 6: Entropy-Loss = [12.43506042 10.63287775]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [11.17353255 11.53396908]
# Particle 15: Entropy-Loss = [11.71418735 12.07462389]
# Particle 16: Entropy-Loss = [13.51637002 12.25484215]
# Particle 17: Entropy-Loss = [10.81309602 11.89440562]
# Particle 18: Entropy-Loss = [10.09222295 11.53396908]
# Particle 19: Entropy-Loss = [9.91200468 9.73178642]
# In results, Iteration 1:
# Particle 0: Entropy-Loss = [13.87680655 10.09222295]
# Particle 1: Entropy-Loss = [11.53396908 13.33615175]
# Particle 2: Entropy-Loss = [12.25484215 11.35375082]
# Particle 3: Entropy-Loss = [13.87680655 12.07462389]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [10.81309602 13.87680655]
# Particle 6: Entropy-Loss = [12.43506042 10.81309602]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [10.99331428 11.17353255]
# Particle 15: Entropy-Loss = [9.55156815 9.37134988]
# Particle 16: Entropy-Loss = [11.35375082 10.27244122]
# Particle 17: Entropy-Loss = [13.69658829 10.63287775]
# Particle 18: Entropy-Loss = [ 9.91200468 10.27244122]
# Particle 19: Entropy-Loss = [9.91200468 9.73178642]
# In results, Iteration 2:
# Particle 0: Entropy-Loss = [12.07462389 10.81309602]
# Particle 1: Entropy-Loss = [11.53396908 13.33615175]
# Particle 2: Entropy-Loss = [12.25484215 11.35375082]
# Particle 3: Entropy-Loss = [13.87680655 12.07462389]
# Particle 4: Entropy-Loss = [13.15593349 12.61527869]
# Particle 5: Entropy-Loss = [10.81309602 13.87680655]
# Particle 6: Entropy-Loss = [12.07462389 10.63287775]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [10.09222295  8.83069508]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [10.45265948  9.55156815]
# Particle 14: Entropy-Loss = [11.35375082 10.27244122]
# Particle 15: Entropy-Loss = [9.55156815 9.37134988]
# Particle 16: Entropy-Loss = [11.35375082 10.27244122]
# Particle 17: Entropy-Loss = [10.09222295 11.17353255]
# Particle 18: Entropy-Loss = [ 9.91200468 10.27244122]
# Particle 19: Entropy-Loss = [13.15593349 12.07462389]
# In results, Iteration 3:
# Particle 0: Entropy-Loss = [13.15593349 11.35375082]
# Particle 1: Entropy-Loss = [11.53396908 13.33615175]
# Particle 2: Entropy-Loss = [11.89440562 10.99331428]
# Particle 3: Entropy-Loss = [13.87680655 12.07462389]
# Particle 4: Entropy-Loss = [11.17353255  9.73178642]
# Particle 5: Entropy-Loss = [14.05702482 10.81309602]
# Particle 6: Entropy-Loss = [12.07462389 11.17353255]
# Particle 7: Entropy-Loss = [11.17353255 10.99331428]
# Particle 8: Entropy-Loss = [10.09222295  9.91200468]
# Particle 9: Entropy-Loss = [ 9.37134988 10.99331428]
# Particle 10: Entropy-Loss = [11.71418735  9.01091335]
# Particle 11: Entropy-Loss = [11.17353255 10.81309602]
# Particle 12: Entropy-Loss = [12.61527869 10.45265948]
# Particle 13: Entropy-Loss = [ 8.29004028 12.61527869]
# Particle 14: Entropy-Loss = [10.63287775  9.19113161]
# Particle 15: Entropy-Loss = [12.25484215  9.19113161]
# Particle 16: Entropy-Loss = [11.35375082 10.27244122]
# Particle 17: Entropy-Loss = [10.09222295 11.17353255]
# Particle 18: Entropy-Loss = [11.71418735  8.47025855]
# Particle 19: Entropy-Loss = [13.15593349 12.07462389]
# In results, Iteration 4:
# Particle 0: Entropy-Loss = [11.71418735 12.43506042]
# Particle 1: Entropy-Loss = [12.61527869 10.45265948]
# Particle 2: Entropy-Loss = [12.61527869 12.61527869]
# Particle 3: Entropy-Loss = [11.71418735 11.53396908]
# Particle 4: Entropy-Loss = [11.17353255  9.73178642]
# Particle 5: Entropy-Loss = [10.99331428 10.09222295]
# Particle 6: Entropy-Loss = [12.07462389 11.17353255]
# Particle 7: Entropy-Loss = [ 9.37134988 10.81309602]
# Particle 8: Entropy-Loss = [ 9.73178642 11.71418735]
# Particle 9: Entropy-Loss = [11.17353255 12.25484215]
# Particle 10: Entropy-Loss = [11.71418735 10.81309602]
# Particle 11: Entropy-Loss = [12.07462389 12.07462389]
# Particle 12: Entropy-Loss = [10.99331428 11.53396908]
# Particle 13: Entropy-Loss = [10.99331428 11.71418735]
# Particle 14: Entropy-Loss = [11.35375082  9.19113161]
# Particle 15: Entropy-Loss = [12.25484215  9.19113161]
# Particle 16: Entropy-Loss = [12.43506042 10.09222295]
# Particle 17: Entropy-Loss = [10.81309602 10.45265948]
# Particle 18: Entropy-Loss = [11.17353255 14.05702482]
# Particle 19: Entropy-Loss = [13.15593349 12.07462389]
# In results, Iteration 5:
# Particle 0: Entropy-Loss = [10.99331428 10.81309602]
# Particle 1: Entropy-Loss = [12.61527869 10.45265948]
# Particle 2: Entropy-Loss = [12.61527869 12.61527869]
# Particle 3: Entropy-Loss = [12.79549695  9.91200468]
# Particle 4: Entropy-Loss = [11.17353255  9.73178642]
# Particle 5: Entropy-Loss = [10.45265948 11.71418735]
# Particle 6: Entropy-Loss = [12.07462389 11.17353255]
# Particle 7: Entropy-Loss = [ 9.37134988 10.81309602]
# Particle 8: Entropy-Loss = [10.99331428 10.63287775]
# Particle 9: Entropy-Loss = [11.53396908 11.53396908]
# Particle 10: Entropy-Loss = [11.17353255 12.43506042]
# Particle 11: Entropy-Loss = [12.07462389 12.07462389]
# Particle 12: Entropy-Loss = [ 7.74938548 11.53396908]
# Particle 13: Entropy-Loss = [11.71418735 12.25484215]
# Particle 14: Entropy-Loss = [11.17353255 11.17353255]
# Particle 15: Entropy-Loss = [12.25484215  9.19113161]
# Particle 16: Entropy-Loss = [12.43506042 10.09222295]
# Particle 17: Entropy-Loss = [10.81309602 10.45265948]
# Particle 18: Entropy-Loss = [12.79549695 11.71418735]
# Particle 19: Entropy-Loss = [11.35375082 10.81309602]
# In results, Iteration 6:
# Particle 0: Entropy-Loss = [13.15593349 11.71418735]
# Particle 1: Entropy-Loss = [12.25484215 11.71418735]
# Particle 2: Entropy-Loss = [11.53396908 10.45265948]
# Particle 3: Entropy-Loss = [10.63287775 10.99331428]
# Particle 4: Entropy-Loss = [ 9.91200468 10.63287775]
# Particle 5: Entropy-Loss = [12.25484215  9.19113161]
# Particle 6: Entropy-Loss = [12.07462389 11.17353255]
# Particle 7: Entropy-Loss = [11.71418735  9.73178642]
# Particle 8: Entropy-Loss = [12.07462389 12.25484215]
# Particle 9: Entropy-Loss = [12.07462389 10.81309602]
# Particle 10: Entropy-Loss = [11.17353255 12.43506042]
# Particle 11: Entropy-Loss = [10.27244122 10.27244122]
# Particle 12: Entropy-Loss = [12.07462389 12.43506042]
# Particle 13: Entropy-Loss = [11.71418735 11.89440562]
# Particle 14: Entropy-Loss = [ 9.73178642 10.27244122]
# Particle 15: Entropy-Loss = [12.25484215  9.19113161]
# Particle 16: Entropy-Loss = [11.35375082 11.89440562]
# Particle 17: Entropy-Loss = [10.45265948 10.63287775]
# Particle 18: Entropy-Loss = [10.63287775 12.97571522]
# Particle 19: Entropy-Loss = [12.43506042 11.35375082]
# Iteration: 7
# In iteration_info, Iteration 7 Particel 0 results: [13.15593349 10.63287775]
# In iteration_info, Iteration 7 Particel 1 results: [12.25484215 11.71418735]
# In iteration_info, Iteration 7 Particel 2 results: [11.53396908 10.45265948]
# In iteration_info, Iteration 7 Particel 3 results: [10.63287775 10.99331428]
# In iteration_info, Iteration 7 Particel 4 results: [ 9.91200468 10.63287775]
# In iteration_info, Iteration 7 Particel 5 results: [10.27244122 10.81309602]
# In iteration_info, Iteration 7 Particel 6 results: [12.07462389 11.17353255]
# /Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/particle_swarm.py:311: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   particle_numeric[mask_low, col_idx] = column_means[col_idx]
# ...
# Particle 8: Entropy-Loss = [12.07462389 12.25484215]
# Particle 9: Entropy-Loss = [12.07462389 10.81309602]
# Particle 10: Entropy-Loss = [11.17353255 12.43506042]
# Particle 11: Entropy-Loss = [10.27244122 10.27244122]
# Particle 12: Entropy-Loss = [12.07462389 12.43506042]
# Particle 13: Entropy-Loss = [11.71418735 11.89440562]
# Particle 14: Entropy-Loss = [ 9.73178642 10.27244122]
# Particle 15: Entropy-Loss = [12.25484215  9.19113161]
# Particle 16: Entropy-Loss = [11.35375082 11.89440562]
# Particle 17: Entropy-Loss = [10.45265948 10.63287775]
# Particle 18: Entropy-Loss = [10.63287775 12.97571522]
# Particle 19: Entropy-Loss = [12.43506042 11.35375082]
# In results, Iteration 7:
# Particle 0: Entropy-Loss = [13.15593349 10.63287775]
# Particle 1: Entropy-Loss = [12.25484215 11.71418735]
# Particle 2: Entropy-Loss = [11.53396908 10.45265948]
# Particle 3: Entropy-Loss = [10.63287775 10.99331428]
# Particle 4: Entropy-Loss = [ 9.91200468 10.63287775]
# Particle 5: Entropy-Loss = [10.27244122 10.81309602]
# Particle 6: Entropy-Loss = [12.07462389 11.17353255]
# Particle 7: Entropy-Loss = [12.43506042 12.07462389]
# Particle 8: Entropy-Loss = [12.25484215 12.25484215]
# Particle 9: Entropy-Loss = [12.97571522  9.55156815]
# Particle 10: Entropy-Loss = [11.35375082 10.09222295]
# Particle 11: Entropy-Loss = [11.53396908 10.09222295]
# Particle 12: Entropy-Loss = [12.07462389 12.25484215]
# Particle 13: Entropy-Loss = [ 8.83069508 10.63287775]
# Particle 14: Entropy-Loss = [ 9.73178642 10.27244122]
# Particle 15: Entropy-Loss = [11.35375082 10.63287775]
# Particle 16: Entropy-Loss = [12.25484215 11.89440562]
# Particle 17: Entropy-Loss = [10.63287775 10.99331428]
# Particle 18: Entropy-Loss = [10.63287775 12.97571522]
# Particle 19: Entropy-Loss = [10.45265948 10.99331428]
# In results, Iteration 8:
# Particle 0: Entropy-Loss = [ 9.73178642 12.97571522]
# Particle 1: Entropy-Loss = [12.25484215 11.71418735]
# Particle 2: Entropy-Loss = [11.71418735 10.45265948]
# Particle 3: Entropy-Loss = [12.07462389 11.89440562]
# Particle 4: Entropy-Loss = [10.27244122 11.35375082]
# Particle 5: Entropy-Loss = [10.45265948 11.71418735]
# Particle 6: Entropy-Loss = [10.99331428  9.73178642]
# Particle 7: Entropy-Loss = [11.35375082  9.55156815]
# Particle 8: Entropy-Loss = [12.25484215 12.97571522]
# Particle 9: Entropy-Loss = [12.97571522  9.55156815]
# Particle 10: Entropy-Loss = [11.35375082 10.09222295]
# Particle 11: Entropy-Loss = [11.71418735 10.45265948]
# Particle 12: Entropy-Loss = [12.07462389 11.89440562]
# Particle 13: Entropy-Loss = [10.09222295 12.07462389]
# Particle 14: Entropy-Loss = [11.53396908 10.81309602]
# Particle 15: Entropy-Loss = [11.35375082 10.63287775]
# Particle 16: Entropy-Loss = [12.79549695 11.89440562]
# Particle 17: Entropy-Loss = [10.27244122 10.27244122]
# Particle 18: Entropy-Loss = [12.07462389  9.91200468]
# Particle 19: Entropy-Loss = [10.63287775 12.61527869]
# In results, Iteration 9:
# Particle 0: Entropy-Loss = [8.29004028 9.91200468]
# Particle 1: Entropy-Loss = [13.87680655 10.63287775]
# Particle 2: Entropy-Loss = [10.99331428 10.27244122]
# Particle 3: Entropy-Loss = [13.15593349 11.89440562]
# Particle 4: Entropy-Loss = [12.25484215 10.63287775]
# Particle 5: Entropy-Loss = [10.45265948 10.63287775]
# Particle 6: Entropy-Loss = [12.25484215 12.79549695]
# Particle 7: Entropy-Loss = [10.81309602 11.89440562]
# Particle 8: Entropy-Loss = [11.17353255  9.91200468]
# Particle 9: Entropy-Loss = [10.45265948 12.43506042]
# Particle 10: Entropy-Loss = [ 9.73178642 11.53396908]
# Particle 11: Entropy-Loss = [9.73178642 8.83069508]
# Particle 12: Entropy-Loss = [10.99331428  9.37134988]
# Particle 13: Entropy-Loss = [11.89440562 10.81309602]
# Particle 14: Entropy-Loss = [11.71418735 10.63287775]
# Particle 15: Entropy-Loss = [11.35375082 10.63287775]
# Particle 16: Entropy-Loss = [11.35375082 10.99331428]
# Particle 17: Entropy-Loss = [9.55156815 9.37134988]
# Particle 18: Entropy-Loss = [12.07462389  9.91200468]
# Particle 19: Entropy-Loss = [10.81309602 11.89440562]
# In results, Iteration 10:
# Particle 0: Entropy-Loss = [10.63287775 12.07462389]
# Particle 1: Entropy-Loss = [11.53396908 12.25484215]
# Particle 2: Entropy-Loss = [10.99331428 10.27244122]
# Particle 3: Entropy-Loss = [11.89440562 12.61527869]
# Particle 4: Entropy-Loss = [ 9.73178642 11.17353255]
# Particle 5: Entropy-Loss = [11.71418735 11.71418735]
# Particle 6: Entropy-Loss = [10.45265948 11.89440562]
# Particle 7: Entropy-Loss = [12.61527869 12.43506042]
# Particle 8: Entropy-Loss = [12.43506042 11.71418735]
# Particle 9: Entropy-Loss = [11.17353255 10.81309602]
# Particle 10: Entropy-Loss = [12.79549695 11.89440562]
# Particle 11: Entropy-Loss = [11.71418735 10.27244122]
# Particle 12: Entropy-Loss = [11.71418735 10.45265948]
# Particle 13: Entropy-Loss = [ 9.91200468 10.27244122]
# Particle 14: Entropy-Loss = [11.71418735 10.63287775]
# Particle 15: Entropy-Loss = [11.35375082 10.63287775]
# Particle 16: Entropy-Loss = [ 9.19113161 10.09222295]
# Particle 17: Entropy-Loss = [13.33615175  8.83069508]
# Particle 18: Entropy-Loss = [12.07462389 11.53396908]
# Particle 19: Entropy-Loss = [11.71418735  8.83069508]
# In results, Iteration 11:
# Particle 0: Entropy-Loss = [11.17353255 11.17353255]
# Particle 1: Entropy-Loss = [11.53396908 12.25484215]
# Particle 2: Entropy-Loss = [12.61527869  9.55156815]
# Particle 3: Entropy-Loss = [10.45265948 12.25484215]
# Particle 4: Entropy-Loss = [13.33615175 13.33615175]
# Particle 5: Entropy-Loss = [12.43506042 11.71418735]
# Particle 6: Entropy-Loss = [11.17353255 11.53396908]
# Particle 7: Entropy-Loss = [11.17353255 11.71418735]
# Particle 8: Entropy-Loss = [11.71418735 11.35375082]
# Particle 9: Entropy-Loss = [11.17353255 11.35375082]
# Particle 10: Entropy-Loss = [11.89440562 11.53396908]
# Particle 11: Entropy-Loss = [12.25484215 11.35375082]
# Particle 12: Entropy-Loss = [10.09222295 10.81309602]
# Particle 13: Entropy-Loss = [10.63287775 12.97571522]
# Particle 14: Entropy-Loss = [10.45265948 10.63287775]
# Particle 15: Entropy-Loss = [11.35375082 10.63287775]
# Particle 16: Entropy-Loss = [11.89440562 10.45265948]
# Particle 17: Entropy-Loss = [10.99331428 10.81309602]
# Particle 18: Entropy-Loss = [11.17353255  9.73178642]
# Particle 19: Entropy-Loss = [11.35375082 10.63287775]
# In results, Iteration 12:
# Particle 0: Entropy-Loss = [11.17353255 11.17353255]
# Particle 1: Entropy-Loss = [13.15593349 12.61527869]
# Particle 2: Entropy-Loss = [12.43506042 11.17353255]
# Particle 3: Entropy-Loss = [ 9.91200468 10.81309602]
# Particle 4: Entropy-Loss = [10.45265948 13.15593349]
# Particle 5: Entropy-Loss = [11.71418735 12.25484215]
# Particle 6: Entropy-Loss = [11.71418735 11.89440562]
# Particle 7: Entropy-Loss = [ 9.91200468 11.17353255]
# Particle 8: Entropy-Loss = [12.25484215 11.35375082]
# Particle 9: Entropy-Loss = [11.71418735 11.89440562]
# Particle 10: Entropy-Loss = [11.35375082 12.07462389]
# Particle 11: Entropy-Loss = [11.35375082 10.99331428]
# Particle 12: Entropy-Loss = [ 9.19113161 14.05702482]
# Particle 13: Entropy-Loss = [13.15593349  9.91200468]
# Particle 14: Entropy-Loss = [ 9.19113161 11.35375082]
# Particle 15: Entropy-Loss = [11.35375082 10.63287775]
# Particle 16: Entropy-Loss = [12.07462389 12.07462389]
# Particle 17: Entropy-Loss = [ 9.91200468 10.09222295]
# Particle 18: Entropy-Loss = [11.71418735 12.07462389]
# Particle 19: Entropy-Loss = [10.63287775 10.27244122]
# In results, Iteration 13:
# Particle 0: Entropy-Loss = [10.27244122  9.91200468]
# Particle 1: Entropy-Loss = [12.61527869 12.43506042]
# Particle 2: Entropy-Loss = [10.81309602 10.09222295]
# Particle 3: Entropy-Loss = [11.89440562 11.89440562]
# Particle 4: Entropy-Loss = [10.81309602 10.99331428]
# Particle 5: Entropy-Loss = [11.17353255 12.43506042]
# Particle 6: Entropy-Loss = [10.45265948 11.71418735]
# Particle 7: Entropy-Loss = [11.53396908 13.33615175]
# Particle 8: Entropy-Loss = [11.17353255 12.07462389]
# Particle 9: Entropy-Loss = [12.97571522 11.89440562]
# Particle 10: Entropy-Loss = [10.99331428 10.09222295]
# Particle 11: Entropy-Loss = [13.87680655 10.63287775]
# Particle 12: Entropy-Loss = [ 9.55156815 11.17353255]
# Particle 13: Entropy-Loss = [10.45265948 12.61527869]
# Particle 14: Entropy-Loss = [ 9.19113161 11.35375082]
# Particle 15: Entropy-Loss = [11.35375082 10.63287775]
# Particle 16: Entropy-Loss = [12.43506042 12.07462389]
# Particle 17: Entropy-Loss = [10.63287775 10.45265948]
# Particle 18: Entropy-Loss = [10.99331428 13.69658829]
# Particle 19: Entropy-Loss = [11.53396908 12.97571522]
# In results, Iteration 14:
# Particle 0: Entropy-Loss = [10.09222295 11.89440562]
# Particle 1: Entropy-Loss = [12.97571522 12.25484215]
# Particle 2: Entropy-Loss = [11.53396908  9.73178642]
# Particle 3: Entropy-Loss = [12.43506042  9.73178642]
# Particle 4: Entropy-Loss = [11.17353255 11.17353255]
# Particle 5: Entropy-Loss = [ 8.29004028 11.17353255]
# Particle 6: Entropy-Loss = [10.63287775 11.35375082]
# Particle 7: Entropy-Loss = [11.53396908 13.33615175]
# Particle 8: Entropy-Loss = [10.45265948 11.53396908]
# Particle 9: Entropy-Loss = [ 9.73178642 10.99331428]
# Particle 10: Entropy-Loss = [11.35375082 12.07462389]
# Particle 11: Entropy-Loss = [12.43506042 10.45265948]
# Particle 12: Entropy-Loss = [10.45265948 12.97571522]
# Particle 13: Entropy-Loss = [11.53396908  9.19113161]
# Particle 14: Entropy-Loss = [ 9.19113161 11.35375082]
# Particle 15: Entropy-Loss = [11.35375082 10.63287775]
# Particle 16: Entropy-Loss = [12.07462389 11.89440562]
# Particle 17: Entropy-Loss = [10.45265948  9.37134988]
# Particle 18: Entropy-Loss = [10.99331428 13.69658829]
# Particle 19: Entropy-Loss = [10.63287775 11.17353255]
# In results, Iteration 15:
# Particle 0: Entropy-Loss = [10.63287775 10.27244122]
# Particle 1: Entropy-Loss = [10.09222295 12.07462389]
# Particle 2: Entropy-Loss = [12.07462389 11.71418735]
# Particle 3: Entropy-Loss = [10.09222295 11.53396908]
# Particle 4: Entropy-Loss = [11.35375082 13.15593349]
# Particle 5: Entropy-Loss = [11.71418735 13.51637002]
# Particle 6: Entropy-Loss = [11.89440562 14.41746136]
# Particle 7: Entropy-Loss = [10.27244122  9.91200468]
# Particle 8: Entropy-Loss = [12.43506042 11.89440562]
# Particle 9: Entropy-Loss = [10.99331428 11.89440562]
# Particle 10: Entropy-Loss = [14.41746136 12.97571522]
# Particle 11: Entropy-Loss = [10.99331428 11.89440562]
# Particle 12: Entropy-Loss = [13.15593349 12.07462389]
# Particle 13: Entropy-Loss = [10.27244122 11.71418735]
# Particle 14: Entropy-Loss = [10.63287775  9.37134988]
# Particle 15: Entropy-Loss = [11.35375082 10.63287775]
# Particle 16: Entropy-Loss = [11.53396908 10.63287775]
# Particle 17: Entropy-Loss = [11.89440562 11.53396908]
# Particle 18: Entropy-Loss = [10.99331428 13.69658829]
# Particle 19: Entropy-Loss = [12.97571522 11.71418735]
# In results, Iteration 16:
# Particle 0: Entropy-Loss = [11.53396908 11.17353255]
# Particle 1: Entropy-Loss = [10.63287775 10.99331428]
# Particle 2: Entropy-Loss = [11.89440562 10.81309602]
# Particle 3: Entropy-Loss = [12.25484215 10.27244122]
# Particle 4: Entropy-Loss = [12.43506042 10.45265948]
# Particle 5: Entropy-Loss = [11.35375082  9.55156815]
# Particle 6: Entropy-Loss = [10.81309602 12.97571522]
# Particle 7: Entropy-Loss = [12.07462389 13.33615175]
# Particle 8: Entropy-Loss = [12.07462389 12.07462389]
# Particle 9: Entropy-Loss = [10.99331428 11.89440562]
# Particle 10: Entropy-Loss = [ 9.91200468 10.63287775]
# Particle 11: Entropy-Loss = [10.09222295 10.81309602]
# Particle 12: Entropy-Loss = [11.71418735 11.71418735]
# Particle 13: Entropy-Loss = [12.07462389  9.91200468]
# Particle 14: Entropy-Loss = [12.61527869 11.71418735]
# Particle 15: Entropy-Loss = [11.35375082 10.63287775]
# Particle 16: Entropy-Loss = [12.43506042 10.45265948]
# Particle 17: Entropy-Loss = [11.89440562 10.45265948]
# Particle 18: Entropy-Loss = [10.99331428 13.69658829]
# Particle 19: Entropy-Loss = [12.43506042 13.15593349]
# In results, Iteration 17:
# Particle 0: Entropy-Loss = [12.97571522 10.99331428]
# Particle 1: Entropy-Loss = [9.91200468 9.91200468]
# Particle 2: Entropy-Loss = [11.71418735 10.99331428]
# Particle 3: Entropy-Loss = [11.71418735 14.05702482]
# Particle 4: Entropy-Loss = [14.05702482 10.63287775]
# Particle 5: Entropy-Loss = [13.33615175 11.89440562]
# Particle 6: Entropy-Loss = [12.61527869 10.63287775]
# Particle 7: Entropy-Loss = [12.07462389 13.33615175]
# Particle 8: Entropy-Loss = [12.61527869 12.25484215]
# Particle 9: Entropy-Loss = [13.51637002 11.53396908]
# Particle 10: Entropy-Loss = [13.69658829 10.81309602]
# Particle 11: Entropy-Loss = [13.15593349  9.37134988]
# Particle 12: Entropy-Loss = [ 9.91200468 11.35375082]
# Particle 13: Entropy-Loss = [12.07462389  7.56916721]
# Particle 14: Entropy-Loss = [12.61527869 11.71418735]
# Particle 15: Entropy-Loss = [11.35375082 10.63287775]
# Particle 16: Entropy-Loss = [10.45265948 10.99331428]
# Particle 17: Entropy-Loss = [10.81309602 11.17353255]
# Particle 18: Entropy-Loss = [10.81309602 12.25484215]
# Particle 19: Entropy-Loss = [10.09222295 12.61527869]
# In results, Iteration 18:
# Particle 0: Entropy-Loss = [11.53396908  9.91200468]
# Particle 1: Entropy-Loss = [11.89440562 13.33615175]
# Particle 2: Entropy-Loss = [12.25484215 11.71418735]
# Particle 3: Entropy-Loss = [12.25484215 12.07462389]
# Particle 4: Entropy-Loss = [12.07462389 11.71418735]
# Particle 5: Entropy-Loss = [11.89440562 11.71418735]
# Particle 6: Entropy-Loss = [10.09222295 12.25484215]
# Particle 7: Entropy-Loss = [10.63287775 13.15593349]
# Particle 8: Entropy-Loss = [11.35375082 12.25484215]
# Particle 9: Entropy-Loss = [10.81309602  9.55156815]
# Particle 10: Entropy-Loss = [12.25484215 11.35375082]
# Particle 11: Entropy-Loss = [10.63287775 12.97571522]
# Particle 12: Entropy-Loss = [12.97571522 10.63287775]
# Particle 13: Entropy-Loss = [10.27244122 12.07462389]
# Particle 14: Entropy-Loss = [12.07462389  8.65047681]
# Particle 15: Entropy-Loss = [11.35375082 10.63287775]
# Particle 16: Entropy-Loss = [11.53396908 11.17353255]
# Particle 17: Entropy-Loss = [12.25484215 10.27244122]
# Particle 18: Entropy-Loss = [10.81309602 11.53396908]
# Particle 19: Entropy-Loss = [10.63287775 11.17353255]
# In results, Iteration 19:
# Particle 0: Entropy-Loss = [ 9.01091335 10.27244122]
# Particle 1: Entropy-Loss = [11.35375082 12.07462389]
# Particle 2: Entropy-Loss = [11.89440562  9.55156815]
# Particle 3: Entropy-Loss = [10.09222295 11.53396908]
# Particle 4: Entropy-Loss = [12.61527869 11.71418735]
# Particle 5: Entropy-Loss = [11.35375082 10.63287775]
# Particle 6: Entropy-Loss = [11.53396908 10.09222295]
# Particle 7: Entropy-Loss = [10.27244122 12.79549695]
# Particle 8: Entropy-Loss = [12.07462389  9.73178642]
# Particle 9: Entropy-Loss = [10.99331428 11.35375082]
# Particle 10: Entropy-Loss = [12.43506042 11.89440562]
# Particle 11: Entropy-Loss = [10.63287775 12.97571522]
# Particle 12: Entropy-Loss = [10.09222295 10.45265948]
# Particle 13: Entropy-Loss = [10.27244122 13.51637002]
# Particle 14: Entropy-Loss = [10.63287775  9.37134988]
# Particle 15: Entropy-Loss = [11.35375082 10.63287775]
# Particle 16: Entropy-Loss = [10.45265948 10.99331428]
# Particle 17: Entropy-Loss = [10.99331428 14.23724309]
# Particle 18: Entropy-Loss = [10.81309602 11.53396908]
# Particle 19: Entropy-Loss = [12.43506042 12.25484215]
# Saved the best anonymized data to /Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/Experiment results/V2/Anonymized Data/best_anonymized_df_k20_ncluster3.csv
# /Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/particle_swarm.py:311: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   particle_numeric[mask_low, col_idx] = column_means[col_idx]
# /Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/particle_swarm.py:312: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   particle_numeric[mask_high, col_idx] = column_means[col_idx]

# %%
results
# Out:
# [[{'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 0,
#    'Particle centroid': array([[44, 'male mar/wid', 'unemp/unskilled non res'],
#           [44, 'male div/sep', 'skilled'],
#           [30, 'female div/dep/mar', 'unskilled resident']], dtype=object),
#    'Accuracy': array([0.68, 0.72]),
#    'Precision': array([0.71014493, 0.81203008]),
#    'Recall': array([0.80327869, 0.77697842]),
#    'F1 score': array([0.75384615, 0.79411765]),
#    'AUC': array([0.64522909, 0.68357118]),
#    'Entropy-Loss': array([11.53396908, 10.09222295]),
#    'TP': array([ 98., 108.]),
#    'TN': array([38., 36.]),
#    'FP': array([40., 25.]),
#    'FN': array([24., 31.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 1,
#    'Particle centroid': array([[51, 'male mar/wid', 'unskilled resident'],
#           [65, 'male single', 'unskilled resident'],
#           [45, 'male single', 'high qualif/self emp/mgmt']], dtype=object),
#    'Accuracy': array([0.67 , 0.725]),
#    'Precision': array([0.77857143, 0.81818182]),
#    'Recall': array([0.75694444, 0.80136986]),
#    'F1 score': array([0.76760563, 0.80968858]),
#    'AUC': array([0.60168651, 0.65994419]),
#    'Entropy-Loss': array([11.89440562,  9.91200468]),
#    'TP': array([109., 117.]),
#    'TN': array([25., 28.]),
#    'FP': array([31., 26.]),
#    'FN': array([35., 29.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 2,
#    'Particle centroid': array([[38, 'male div/sep', 'high qualif/self emp/mgmt'],
#           [40, 'male div/sep', 'unemp/unskilled non res'],
#           [25, 'male single', 'unskilled resident']], dtype=object),
#    'Accuracy': array([0.665, 0.71 ]),
#    'Precision': array([0.7414966 , 0.83870968]),
#    'Recall': array([0.78985507, 0.73239437]),
#    'F1 score': array([0.76491228, 0.78195489]),
#    'AUC': array([0.58847592, 0.69378339]),
#    'Entropy-Loss': array([12.07462389, 10.45265948]),
#    'TP': array([109., 104.]),
#    'TN': array([24., 38.]),
#    'FP': array([38., 20.]),
#    'FN': array([29., 38.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 3,
#    'Particle centroid': array([[37, 'male div/sep', 'skilled'],
#           [45, 'female div/dep/mar', 'unemp/unskilled non res'],
#           [34, 'male div/sep', 'skilled']], dtype=object),
#    'Accuracy': array([0.66 , 0.745]),
#    'Precision': array([0.73049645, 0.8115942 ]),
#    'Recall': array([0.77443609, 0.81751825]),
#    'F1 score': array([0.75182482, 0.81454545]),
#    'AUC': array([0.60363596, 0.70240992]),
#    'Entropy-Loss': array([12.25484215,  9.19113161]),
#    'TP': array([103., 112.]),
#    'TN': array([29., 37.]),
#    'FP': array([38., 26.]),
#    'FN': array([30., 25.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 4,
#    'Particle centroid': array([[30, 'male div/sep', 'unskilled resident'],
#           [53, 'female div/dep/mar', 'unskilled resident'],
#           [34, 'male single', 'unemp/unskilled non res']], dtype=object),
#    'Accuracy': array([0.635, 0.65 ]),
#    'Precision': array([0.76923077, 0.77941176]),
#    'Recall': array([0.6993007, 0.7260274]),
#    'F1 score': array([0.73260073, 0.75177305]),
#    'AUC': array([0.58649245, 0.58523592]),
#    'Entropy-Loss': array([13.15593349, 12.61527869]),
#    'TP': array([100., 106.]),
#    'TN': array([27., 24.]),
#    'FP': array([30., 30.]),
#    'FN': array([43., 40.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 5,
#    'Particle centroid': array([[21, 'male mar/wid', 'unskilled resident'],
#           [19, 'female div/dep/mar', 'unskilled resident'],
#           [71, 'male mar/wid', 'unskilled resident']], dtype=object),
#    'Accuracy': array([0.68 , 0.685]),
#    'Precision': array([0.77536232, 0.76551724]),
#    'Recall': array([0.76428571, 0.79285714]),
#    'F1 score': array([0.76978417, 0.77894737]),
#    'AUC': array([0.62380952, 0.61309524]),
#    'Entropy-Loss': array([11.53396908, 11.35375082]),
#    'TP': array([107., 111.]),
#    'TN': array([29., 26.]),
#    'FP': array([31., 34.]),
#    'FN': array([33., 29.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 2,
#    'num_violated_clusters': 1,
#    'num_violating_records_before_adjusting': 10,
#    'num_retained_records': 40,
#    'num_excess_records': 950,
#    'num_fixed_clusters': 1,
#    'num_used_excess': 10,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 6,
#    'Particle centroid': array([[61, 'female div/dep/mar', 'skilled'],
#           [35, 'male div/sep', 'skilled'],
#           [27, 'male single', 'unemp/unskilled non res']], dtype=object),
#    'Accuracy': array([0.655, 0.705]),
#    'Precision': array([0.76119403, 0.81679389]),
#    'Recall': array([0.73381295, 0.75352113]),
#    'F1 score': array([0.74725275, 0.78388278]),
#    'AUC': array([0.60461139, 0.66986401]),
#    'Entropy-Loss': array([12.43506042, 10.63287775]),
#    'TP': array([102., 107.]),
#    'TN': array([29., 34.]),
#    'FP': array([32., 24.]),
#    'FN': array([37., 35.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 7,
#    'Particle centroid': array([[36, 'male div/sep', 'high qualif/self emp/mgmt'],
#           [59, 'male div/sep', 'high qualif/self emp/mgmt'],
#           [31, 'male single', 'high qualif/self emp/mgmt']], dtype=object),
#    'Accuracy': array([0.69 , 0.695]),
#    'Precision': array([0.73758865, 0.848     ]),
#    'Recall': array([0.80620155, 0.71621622]),
#    'F1 score': array([0.77037037, 0.77655678]),
#    'AUC': array([0.64253739, 0.6754158 ]),
#    'Entropy-Loss': array([11.17353255, 10.99331428]),
#    'TP': array([104., 106.]),
#    'TN': array([34., 33.]),
#    'FP': array([37., 19.]),
#    'FN': array([25., 42.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 8,
#    'Particle centroid': array([[34, 'male single', 'skilled'],
#           [23, 'male div/sep', 'high qualif/self emp/mgmt'],
#           [37, 'female div/dep/mar', 'unskilled resident']], dtype=object),
#    'Accuracy': array([0.72 , 0.725]),
#    'Precision': array([0.8203125 , 0.79577465]),
#    'Recall': array([0.76086957, 0.81294964]),
#    'F1 score': array([0.78947368, 0.80427046]),
#    'AUC': array([0.69495091, 0.6687699 ]),
#    'Entropy-Loss': array([10.09222295,  9.91200468]),
#    'TP': array([105., 113.]),
#    'TN': array([39., 32.]),
#    'FP': array([23., 29.]),
#    'FN': array([33., 26.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 9,
#    'Particle centroid': array([[68, 'male div/sep', 'high qualif/self emp/mgmt'],
#           [51, 'male single', 'unemp/unskilled non res'],
#           [46, 'male mar/wid', 'unskilled resident']], dtype=object),
#    'Accuracy': array([0.72 , 0.755]),
#    'Precision': array([0.8115942 , 0.85815603]),
#    'Recall': array([0.78873239, 0.80666667]),
#    'F1 score': array([0.8       , 0.83161512]),
#    'AUC': array([0.67022827, 0.70333333]),
#    'Entropy-Loss': array([10.09222295,  8.83069508]),
#    'TP': array([112., 121.]),
#    'TN': array([32., 30.]),
#    'FP': array([26., 20.]),
#    'FN': array([30., 29.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 10,
#    'Particle centroid': array([[68, 'male mar/wid', 'unemp/unskilled non res'],
#           [20, 'male mar/wid', 'unemp/unskilled non res'],
#           [49, 'male div/sep', 'unskilled resident']], dtype=object),
#    'Accuracy': array([0.675, 0.75 ]),
#    'Precision': array([0.76642336, 0.81818182]),
#    'Recall': array([0.76086957, 0.82978723]),
#    'F1 score': array([0.76363636, 0.82394366]),
#    'AUC': array([0.62237027, 0.69455463]),
#    'Entropy-Loss': array([11.71418735,  9.01091335]),
#    'TP': array([105., 117.]),
#    'TN': array([30., 33.]),
#    'FP': array([32., 26.]),
#    'FN': array([33., 24.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 11,
#    'Particle centroid': array([[66, 'male div/sep', 'unemp/unskilled non res'],
#           [53, 'male single', 'skilled'],
#           [34, 'male mar/wid', 'unskilled resident']], dtype=object),
#    'Accuracy': array([0.69, 0.7 ]),
#    'Precision': array([0.77702703, 0.78571429]),
#    'Recall': array([0.79861111, 0.75      ]),
#    'F1 score': array([0.78767123, 0.76744186]),
#    'AUC': array([0.6046627 , 0.67647059]),
#    'Entropy-Loss': array([11.17353255, 10.81309602]),
#    'TP': array([115.,  99.]),
#    'TN': array([23., 41.]),
#    'FP': array([33., 27.]),
#    'FN': array([29., 33.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 12,
#    'Particle centroid': array([[74, 'male single', 'unskilled resident'],
#           [65, 'male single', 'unemp/unskilled non res'],
#           [50, 'male single', 'unskilled resident']], dtype=object),
#    'Accuracy': array([0.695, 0.74 ]),
#    'Precision': array([0.82575758, 0.8       ]),
#    'Recall': array([0.7414966 , 0.82352941]),
#    'F1 score': array([0.78136201, 0.8115942 ]),
#    'AUC': array([0.65376717, 0.69301471]),
#    'Entropy-Loss': array([10.99331428,  9.37134988]),
#    'TP': array([109., 112.]),
#    'TN': array([30., 36.]),
#    'FP': array([23., 28.]),
#    'FN': array([38., 24.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 2,
#    'num_violated_clusters': 1,
#    'num_violating_records_before_adjusting': 7,
#    'num_retained_records': 40,
#    'num_excess_records': 953,
#    'num_fixed_clusters': 1,
#    'num_used_excess': 13,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 13,
#    'Particle centroid': array([[50, 'male div/sep', 'skilled'],
#           [21, 'male div/sep', 'skilled'],
#           [23, 'female div/dep/mar', 'unskilled resident']], dtype=object),
#    'Accuracy': array([0.71 , 0.735]),
#    'Precision': array([0.81690141, 0.82835821]),
#    'Recall': array([0.78378378, 0.78723404]),
#    'F1 score': array([0.8       , 0.80727273]),
#    'AUC': array([0.64189189, 0.69870177]),
#    'Entropy-Loss': array([10.45265948,  9.55156815]),
#    'TP': array([116., 111.]),
#    'TN': array([26., 36.]),
#    'FP': array([26., 23.]),
#    'FN': array([32., 30.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 14,
#    'Particle centroid': array([[42, 'female div/dep/mar', 'skilled'],
#           [41, 'male mar/wid', 'high qualif/self emp/mgmt'],
#           [42, 'male div/sep', 'high qualif/self emp/mgmt']], dtype=object),
#    'Accuracy': array([0.69, 0.68]),
#    'Precision': array([0.77697842, 0.75362319]),
#    'Recall': array([0.77697842, 0.7761194 ]),
#    'F1 score': array([0.77697842, 0.76470588]),
#    'AUC': array([0.63439085, 0.63048394]),
#    'Entropy-Loss': array([11.17353255, 11.53396908]),
#    'TP': array([108., 104.]),
#    'TN': array([30., 32.]),
#    'FP': array([31., 34.]),
#    'FN': array([31., 30.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 15,
#    'Particle centroid': array([[44, 'female div/dep/mar', 'high qualif/self emp/mgmt'],
#           [42, 'male single', 'skilled'],
#           [52, 'female div/dep/mar', 'high qualif/self emp/mgmt']],
#          dtype=object),
#    'Accuracy': array([0.675, 0.665]),
#    'Precision': array([0.76760563, 0.74242424]),
#    'Recall': array([0.77304965, 0.7480916 ]),
#    'F1 score': array([0.77031802, 0.74524715]),
#    'AUC': array([0.60686381, 0.62766899]),
#    'Entropy-Loss': array([11.71418735, 12.07462389]),
#    'TP': array([109.,  98.]),
#    'TN': array([26., 35.]),
#    'FP': array([33., 34.]),
#    'FN': array([32., 33.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 16,
#    'Particle centroid': array([[63, 'male mar/wid', 'high qualif/self emp/mgmt'],
#           [71, 'female div/dep/mar', 'high qualif/self emp/mgmt'],
#           [73, 'male div/sep', 'skilled']], dtype=object),
#    'Accuracy': array([0.625, 0.66 ]),
#    'Precision': array([0.72916667, 0.76335878]),
#    'Recall': array([0.74468085, 0.72992701]),
#    'F1 score': array([0.73684211, 0.74626866]),
#    'AUC': array([0.54183195, 0.61893176]),
#    'Entropy-Loss': array([13.51637002, 12.25484215]),
#    'TP': array([105., 100.]),
#    'TN': array([20., 32.]),
#    'FP': array([39., 31.]),
#    'FN': array([36., 37.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 1,
#    'num_violated_clusters': 2,
#    'num_violating_records_before_adjusting': 12,
#    'num_retained_records': 20,
#    'num_excess_records': 968,
#    'num_fixed_clusters': 2,
#    'num_used_excess': 28,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 17,
#    'Particle centroid': array([[64, 'male div/sep', 'unskilled resident'],
#           [68, 'male single', 'unemp/unskilled non res'],
#           [34, 'male div/sep', 'unemp/unskilled non res']], dtype=object),
#    'Accuracy': array([0.7 , 0.67]),
#    'Precision': array([0.81746032, 0.74626866]),
#    'Recall': array([0.73571429, 0.75757576]),
#    'F1 score': array([0.77443609, 0.7518797 ]),
#    'AUC': array([0.67619048, 0.62878788]),
#    'Entropy-Loss': array([10.81309602, 11.89440562]),
#    'TP': array([103., 100.]),
#    'TN': array([37., 34.]),
#    'FP': array([23., 34.]),
#    'FN': array([37., 32.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 2,
#    'num_violated_clusters': 1,
#    'num_violating_records_before_adjusting': 16,
#    'num_retained_records': 40,
#    'num_excess_records': 944,
#    'num_fixed_clusters': 1,
#    'num_used_excess': 4,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 18,
#    'Particle centroid': array([[44, 'male mar/wid', 'unemp/unskilled non res'],
#           [44, 'male mar/wid', 'unskilled resident'],
#           [55, 'male single', 'unemp/unskilled non res']], dtype=object),
#    'Accuracy': array([0.72, 0.68]),
#    'Precision': array([0.77857143, 0.78030303]),
#    'Recall': array([0.81343284, 0.74637681]),
#    'F1 score': array([0.79562044, 0.76296296]),
#    'AUC': array([0.67186793, 0.63931744]),
#    'Entropy-Loss': array([10.09222295, 11.53396908]),
#    'TP': array([109., 103.]),
#    'TN': array([35., 33.]),
#    'FP': array([31., 29.]),
#    'FN': array([25., 35.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 0,
#    'Particle': 19,
#    'Particle centroid': array([[38, 'male div/sep', 'skilled'],
#           [36, 'male div/sep', 'unskilled resident'],
#           [37, 'male single', 'high qualif/self emp/mgmt']], dtype=object),
#    'Accuracy': array([0.725, 0.73 ]),
#    'Precision': array([0.83333333, 0.81060606]),
#    'Recall': array([0.76923077, 0.78676471]),
#    'F1 score': array([0.8       , 0.79850746]),
#    'AUC': array([0.69163293, 0.69806985]),
#    'Entropy-Loss': array([9.91200468, 9.73178642]),
#    'TP': array([110., 107.]),
#    'TN': array([35., 39.]),
#    'FP': array([22., 25.]),
#    'FN': array([33., 29.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0}],
#  [{'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 0,
#    'Particle centroid': array([[43.98161344445008, 'male mar/wid', 'unemp/unskilled non res'],
#           [43.97548459260011, 'male div/sep', 'skilled'],
#           [30.021450981474903, 'female div/dep/mar', 'unskilled resident']],
#          dtype=object),
#    'Accuracy': array([0.615, 0.72 ]),
#    'Precision': array([0.66911765, 0.8       ]),
#    'Recall': array([0.7398374, 0.8      ]),
#    'F1 score': array([0.7027027, 0.8      ]),
#    'AUC': array([0.57771091, 0.66666667]),
#    'Entropy-Loss': array([13.87680655, 10.09222295]),
#    'TP': array([ 91., 112.]),
#    'TN': array([32., 32.]),
#    'FP': array([45., 28.]),
#    'FN': array([32., 28.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 1,
#    'Particle centroid': array([[50.97086964261097, 'male mar/wid', 'unskilled resident'],
#           [64.93501689505526, 'male single', 'unskilled resident'],
#           [44.98207362622214, 'male single', 'high qualif/self emp/mgmt']],
#          dtype=object),
#    'Accuracy': array([0.68, 0.63]),
#    'Precision': array([0.77241379, 0.75555556]),
#    'Recall': array([0.78321678, 0.71328671]),
#    'F1 score': array([0.77777778, 0.73381295]),
#    'AUC': array([0.60213471, 0.56716967]),
#    'Entropy-Loss': array([11.53396908, 13.33615175]),
#    'TP': array([112., 102.]),
#    'TN': array([24., 24.]),
#    'FP': array([33., 33.]),
#    'FN': array([31., 41.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 2,
#    'Particle centroid': array([[38.0, 'male div/sep', 'high qualif/self emp/mgmt'],
#           [39.960694128254694, 'male div/sep', 'unemp/unskilled non res'],
#           [25.117917615235925, 'male single', 'unskilled resident']],
#          dtype=object),
#    'Accuracy': array([0.66 , 0.685]),
#    'Precision': array([0.71830986, 0.76923077]),
#    'Recall': array([0.78461538, 0.78571429]),
#    'F1 score': array([0.75      , 0.77738516]),
#    'AUC': array([0.60659341, 0.61785714]),
#    'Entropy-Loss': array([12.25484215, 11.35375082]),
#    'TP': array([102., 110.]),
#    'TN': array([30., 27.]),
#    'FP': array([40., 33.]),
#    'FN': array([28., 30.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 3,
#    'Particle centroid': array([[37.00772568106191, 'male div/sep', 'skilled'],
#           [44.93046887044278, 'female div/dep/mar',
#            'unemp/unskilled non res'],
#           [34.02317704318574, 'male div/sep', 'skilled']], dtype=object),
#    'Accuracy': array([0.615, 0.665]),
#    'Precision': array([0.70138889, 0.75694444]),
#    'Recall': array([0.74814815, 0.77304965]),
#    'F1 score': array([0.72401434, 0.76491228]),
#    'AUC': array([0.54330484, 0.58991465]),
#    'Entropy-Loss': array([13.87680655, 12.07462389]),
#    'TP': array([101., 109.]),
#    'TN': array([22., 24.]),
#    'FP': array([43., 35.]),
#    'FN': array([34., 32.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 4,
#    'Particle centroid': array([[30.02631401213783, 'male div/sep', 'unskilled resident'],
#           [52.94408272420711, 'female div/dep/mar', 'unskilled resident'],
#           [34.009867754551685, 'male single', 'unemp/unskilled non res']],
#          dtype=object),
#    'Accuracy': array([0.635, 0.65 ]),
#    'Precision': array([0.76923077, 0.77941176]),
#    'Recall': array([0.6993007, 0.7260274]),
#    'F1 score': array([0.73260073, 0.75177305]),
#    'AUC': array([0.58649245, 0.58523592]),
#    'Entropy-Loss': array([13.15593349, 12.61527869]),
#    'TP': array([100., 106.]),
#    'TN': array([27., 24.]),
#    'FP': array([30., 30.]),
#    'FN': array([43., 40.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 5,
#    'Particle centroid': array([[21.038177790943543, 'male mar/wid', 'unskilled resident'],
#           [19.038177790943543, 'female div/dep/mar', 'unskilled resident'],
#           [70.92364441811291, 'male mar/wid', 'unskilled resident']],
#          dtype=object),
#    'Accuracy': array([0.7  , 0.615]),
#    'Precision': array([0.76811594, 0.72868217]),
#    'Recall': array([0.79104478, 0.69117647]),
#    'F1 score': array([0.77941176, 0.70943396]),
#    'AUC': array([0.65309815, 0.57215074]),
#    'Entropy-Loss': array([10.81309602, 13.87680655]),
#    'TP': array([106.,  94.]),
#    'TN': array([34., 29.]),
#    'FP': array([32., 35.]),
#    'FN': array([28., 42.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 2,
#    'num_violated_clusters': 1,
#    'num_violating_records_before_adjusting': 13,
#    'num_retained_records': 40,
#    'num_excess_records': 947,
#    'num_fixed_clusters': 1,
#    'num_used_excess': 7,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 6,
#    'Particle centroid': array([[60.82355794817796, 'female div/dep/mar', 'skilled'],
#           [35.00767139355748, 'male div/sep', 'skilled'],
#           [27.0767139355748, 'male single', 'unemp/unskilled non res']],
#          dtype=object),
#    'Accuracy': array([0.655, 0.7  ]),
#    'Precision': array([0.79230769, 0.81889764]),
#    'Recall': array([0.71034483, 0.73758865]),
#    'F1 score': array([0.74909091, 0.7761194 ]),
#    'AUC': array([0.60971787, 0.67387907]),
#    'Entropy-Loss': array([12.43506042, 10.81309602]),
#    'TP': array([103., 104.]),
#    'TN': array([28., 36.]),
#    'FP': array([27., 23.]),
#    'FN': array([42., 37.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 7,
#    'Particle centroid': array([[36.00511877212081, 'male div/sep', 'high qualif/self emp/mgmt'],
#           [58.9411341206107, 'male div/sep', 'high qualif/self emp/mgmt'],
#           [31.015356316362425, 'male single', 'high qualif/self emp/mgmt']],
#          dtype=object),
#    'Accuracy': array([0.69 , 0.695]),
#    'Precision': array([0.73758865, 0.848     ]),
#    'Recall': array([0.80620155, 0.71621622]),
#    'F1 score': array([0.77037037, 0.77655678]),
#    'AUC': array([0.64253739, 0.6754158 ]),
#    'Entropy-Loss': array([11.17353255, 10.99331428]),
#    'TP': array([104., 106.]),
#    'TN': array([34., 33.]),
#    'FP': array([37., 19.]),
#    'FN': array([25., 42.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 8,
#    'Particle centroid': array([[34.03056679654816, 'male single', 'skilled'],
#           [23.09934208878152, 'male div/sep', 'high qualif/self emp/mgmt'],
#           [37.0, 'female div/dep/mar', 'unskilled resident']], dtype=object),
#    'Accuracy': array([0.72 , 0.725]),
#    'Precision': array([0.8203125 , 0.79577465]),
#    'Recall': array([0.76086957, 0.81294964]),
#    'F1 score': array([0.78947368, 0.80427046]),
#    'AUC': array([0.69495091, 0.6687699 ]),
#    'Entropy-Loss': array([10.09222295,  9.91200468]),
#    'TP': array([105., 113.]),
#    'TN': array([39., 32.]),
#    'FP': array([23., 29.]),
#    'FN': array([33., 26.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 9,
#    'Particle centroid': array([[67.7546703958804, 'male div/sep', 'high qualif/self emp/mgmt'],
#           [50.8773351979402, 'male single', 'unemp/unskilled non res'],
#           [45.92640111876412, 'male mar/wid', 'unskilled resident']],
#          dtype=object),
#    'Accuracy': array([0.72 , 0.755]),
#    'Precision': array([0.8115942 , 0.85815603]),
#    'Recall': array([0.78873239, 0.80666667]),
#    'F1 score': array([0.8       , 0.83161512]),
#    'AUC': array([0.67022827, 0.70333333]),
#    'Entropy-Loss': array([10.09222295,  8.83069508]),
#    'TP': array([112., 121.]),
#    'TN': array([32., 30.]),
#    'FP': array([26., 20.]),
#    'FN': array([30., 29.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 10,
#    'Particle centroid': array([[67.90779006694814, 'male mar/wid', 'unemp/unskilled non res'],
#           [20.04917863096099, 'male mar/wid', 'unemp/unskilled non res'],
#           [48.963116026779254, 'male div/sep', 'unskilled resident']],
#          dtype=object),
#    'Accuracy': array([0.675, 0.75 ]),
#    'Precision': array([0.76642336, 0.81818182]),
#    'Recall': array([0.76086957, 0.82978723]),
#    'F1 score': array([0.76363636, 0.82394366]),
#    'AUC': array([0.62237027, 0.69455463]),
#    'Entropy-Loss': array([11.71418735,  9.01091335]),
#    'TP': array([105., 117.]),
#    'TN': array([30., 33.]),
#    'FP': array([32., 26.]),
#    'FN': array([33., 24.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 11,
#    'Particle centroid': array([[65.93235634570061, 'male div/sep', 'unemp/unskilled non res'],
#           [52.958930638461084, 'male single', 'skilled'],
#           [34.00724753438922, 'male mar/wid', 'unskilled resident']],
#          dtype=object),
#    'Accuracy': array([0.69, 0.7 ]),
#    'Precision': array([0.77702703, 0.78571429]),
#    'Recall': array([0.79861111, 0.75      ]),
#    'F1 score': array([0.78767123, 0.76744186]),
#    'AUC': array([0.6046627 , 0.67647059]),
#    'Entropy-Loss': array([11.17353255, 10.81309602]),
#    'TP': array([115.,  99.]),
#    'TN': array([23., 41.]),
#    'FP': array([33., 27.]),
#    'FN': array([29., 33.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 12,
#    'Particle centroid': array([[73.70729329729944, 'male single', 'unskilled resident'],
#           [64.76420848949122, 'male single', 'unemp/unskilled non res'],
#           [49.894300357358134, 'male single', 'unskilled resident']],
#          dtype=object),
#    'Accuracy': array([0.695, 0.74 ]),
#    'Precision': array([0.82575758, 0.8       ]),
#    'Recall': array([0.7414966 , 0.82352941]),
#    'F1 score': array([0.78136201, 0.8115942 ]),
#    'AUC': array([0.65376717, 0.69301471]),
#    'Entropy-Loss': array([10.99331428,  9.37134988]),
#    'TP': array([109., 112.]),
#    'TN': array([30., 36.]),
#    'FP': array([23., 28.]),
#    'FN': array([38., 24.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 2,
#    'num_violated_clusters': 1,
#    'num_violating_records_before_adjusting': 7,
#    'num_retained_records': 40,
#    'num_excess_records': 953,
#    'num_fixed_clusters': 1,
#    'num_used_excess': 13,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 13,
#    'Particle centroid': array([[49.947001578195035, 'male div/sep', 'skilled'],
#           [21.06624802725621, 'male div/sep', 'skilled'],
#           [23.061831492105796, 'female div/dep/mar', 'unskilled resident']],
#          dtype=object),
#    'Accuracy': array([0.71 , 0.735]),
#    'Precision': array([0.81690141, 0.82835821]),
#    'Recall': array([0.78378378, 0.78723404]),
#    'F1 score': array([0.8       , 0.80727273]),
#    'AUC': array([0.64189189, 0.69870177]),
#    'Entropy-Loss': array([10.45265948,  9.55156815]),
#    'TP': array([116., 111.]),
#    'TN': array([26., 36.]),
#    'FP': array([26., 23.]),
#    'FN': array([32., 30.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 14,
#    'Particle centroid': array([[41.96981402378115, 'female div/dep/mar', 'skilled'],
#           [40.96226752972643, 'male mar/wid', 'high qualif/self emp/mgmt'],
#           [41.96226752972643, 'male div/sep', 'high qualif/self emp/mgmt']],
#          dtype=object),
#    'Accuracy': array([0.695, 0.69 ]),
#    'Precision': array([0.77857143, 0.76470588]),
#    'Recall': array([0.78417266, 0.7761194 ]),
#    'F1 score': array([0.78136201, 0.77037037]),
#    'AUC': array([0.63798797, 0.64563546]),
#    'Entropy-Loss': array([10.99331428, 11.17353255]),
#    'TP': array([109., 104.]),
#    'TN': array([30., 34.]),
#    'FP': array([31., 32.]),
#    'FN': array([30., 30.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 15,
#    'Particle centroid': array([[43.958348393300234, 'female div/dep/mar',
#            'high qualif/self emp/mgmt'],
#           [41.958348393300234, 'male single', 'skilled'],
#           [51.89587098325058, 'female div/dep/mar',
#            'high qualif/self emp/mgmt']], dtype=object),
#    'Accuracy': array([0.735, 0.74 ]),
#    'Precision': array([0.80555556, 0.80405405]),
#    'Recall': array([0.82269504, 0.83802817]),
#    'F1 score': array([0.81403509, 0.82068966]),
#    'AUC': array([0.67405938, 0.66901408]),
#    'Entropy-Loss': array([9.55156815, 9.37134988]),
#    'TP': array([116., 119.]),
#    'TN': array([31., 29.]),
#    'FP': array([28., 29.]),
#    'FN': array([25., 23.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 16,
#    'Particle centroid': array([[62.892679702427, 'male mar/wid', 'high qualif/self emp/mgmt'],
#           [70.8497515833978, 'female div/dep/mar',
#            'high qualif/self emp/mgmt'],
#           [72.84545877149489, 'male div/sep', 'skilled']], dtype=object),
#    'Accuracy': array([0.685, 0.715]),
#    'Precision': array([0.75342466, 0.78014184]),
#    'Recall': array([0.80291971, 0.80882353]),
#    'F1 score': array([0.77738516, 0.79422383]),
#    'AUC': array([0.61574557, 0.66222426]),
#    'Entropy-Loss': array([11.35375082, 10.27244122]),
#    'TP': array([110., 110.]),
#    'TN': array([27., 33.]),
#    'FP': array([36., 31.]),
#    'FN': array([27., 26.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 1,
#    'num_violated_clusters': 2,
#    'num_violating_records_before_adjusting': 13,
#    'num_retained_records': 20,
#    'num_excess_records': 967,
#    'num_fixed_clusters': 2,
#    'num_used_excess': 27,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 17,
#    'Particle centroid': array([[63.92807974406811, 'male div/sep', 'unskilled resident'],
#           [67.91148276192997, 'male single', 'unemp/unskilled non res'],
#           [34.00829849106906, 'male div/sep', 'unemp/unskilled non res']],
#          dtype=object),
#    'Accuracy': array([0.62 , 0.705]),
#    'Precision': array([0.75423729, 0.8       ]),
#    'Recall': array([0.65441176, 0.74626866]),
#    'F1 score': array([0.7007874 , 0.77220077]),
#    'AUC': array([0.60064338, 0.68374039]),
#    'Entropy-Loss': array([13.69658829, 10.63287775]),
#    'TP': array([ 89., 100.]),
#    'TN': array([35., 41.]),
#    'FP': array([29., 25.]),
#    'FN': array([47., 34.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 2,
#    'num_violated_clusters': 1,
#    'num_violating_records_before_adjusting': 17,
#    'num_retained_records': 40,
#    'num_excess_records': 943,
#    'num_fixed_clusters': 1,
#    'num_used_excess': 3,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 18,
#    'Particle centroid': array([[43.99806052577781, 'male mar/wid', 'unemp/unskilled non res'],
#           [43.99741403437041, 'male mar/wid', 'unskilled resident'],
#           [54.99418157733342, 'male single', 'unemp/unskilled non res']],
#          dtype=object),
#    'Accuracy': array([0.725, 0.715]),
#    'Precision': array([0.8046875 , 0.79166667]),
#    'Recall': array([0.77443609, 0.80851064]),
#    'F1 score': array([0.78927203, 0.8       ]),
#    'AUC': array([0.70065088, 0.65001803]),
#    'Entropy-Loss': array([ 9.91200468, 10.27244122]),
#    'TP': array([103., 114.]),
#    'TN': array([42., 29.]),
#    'FP': array([25., 30.]),
#    'FN': array([30., 27.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 1,
#    'Particle': 19,
#    'Particle centroid': array([[38.0, 'male div/sep', 'skilled'],
#           [36.0, 'male div/sep', 'unskilled resident'],
#           [37.0, 'male single', 'high qualif/self emp/mgmt']], dtype=object),
#    'Accuracy': array([0.725, 0.73 ]),
#    'Precision': array([0.83333333, 0.81060606]),
#    'Recall': array([0.76923077, 0.78676471]),
#    'F1 score': array([0.8       , 0.79850746]),
#    'AUC': array([0.69163293, 0.69806985]),
#    'Entropy-Loss': array([9.91200468, 9.73178642]),
#    'TP': array([110., 107.]),
#    'TN': array([35., 39.]),
#    'FP': array([22., 25.]),
#    'FN': array([33., 29.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0}],
#  [{'ML model': 'DT',
#    'Iteration': 2,
#    'Particle': 0,
#    'Particle centroid': array([[43.96344467144488, 'male mar/wid', 'unemp/unskilled non res'],
#           [43.939450157461415, 'male div/sep', 'skilled'],
#           [30.172551332430317, 'female div/dep/mar', 'unskilled resident']],
#          dtype=object),
#    'Accuracy': array([0.665, 0.7  ]),
#    'Precision': array([0.78125   , 0.77372263]),
#    'Recall': array([0.71942446, 0.78518519]),
#    'F1 score': array([0.74906367, 0.77941176]),
#    'AUC': array([0.63020403, 0.65413105]),
#    'Entropy-Loss': array([12.07462389, 10.81309602]),
#    'TP': array([100., 106.]),
#    'TN': array([33., 34.]),
#    'FP': array([28., 31.]),
#    'FN': array([39., 29.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 2,
#    'Particle': 1,
#    'Particle centroid': array([[50.89754238291346, 'male mar/wid', 'unskilled resident'],
#           [64.7246046318263, 'male single', 'unskilled resident'],
#           [45.008666888635894, 'male single', 'high qualif/self emp/mgmt']],
#          dtype=object),
#    'Accuracy': array([0.68, 0.63]),
#    'Precision': array([0.77241379, 0.75555556]),
#    'Recall': array([0.78321678, 0.71328671]),
#    'F1 score': array([0.77777778, 0.73381295]),
#    'AUC': array([0.60213471, 0.56716967]),
#    'Entropy-Loss': array([11.53396908, 13.33615175]),
#    'TP': array([112., 102.]),
#    'TN': array([24., 24.]),
#    'FP': array([33., 33.]),
#    'FN': array([31., 41.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 2,
#    'Particle': 2,
#    'Particle centroid': array([[38.024659509524824, 'male div/sep', 'high qualif/self emp/mgmt'],
#           [39.930202816438296, 'male div/sep', 'unemp/unskilled non res'],
#           [25.345018853071654, 'male single', 'unskilled resident']],
#          dtype=object),
#    'Accuracy': array([0.66 , 0.685]),
#    'Precision': array([0.71830986, 0.76923077]),
#    'Recall': array([0.78461538, 0.78571429]),
#    'F1 score': array([0.75      , 0.77738516]),
#    'AUC': array([0.60659341, 0.61785714]),
#    'Entropy-Loss': array([12.25484215, 11.35375082]),
#    'TP': array([102., 110.]),
#    'TN': array([30., 27.]),
#    'FP': array([40., 33.]),
#    'FN': array([28., 30.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 2,
#    'Particle': 3,
#    'Particle centroid': array([[37.046976227101574, 'male div/sep', 'skilled'],
#           [44.84788737591187, 'female div/dep/mar',
#            'unemp/unskilled non res'],
#           [34.12739501031342, 'male div/sep', 'skilled']], dtype=object),
#    'Accuracy': array([0.615, 0.665]),
#    'Precision': array([0.70138889, 0.75694444]),
#    'Recall': array([0.74814815, 0.77304965]),
#    'F1 score': array([0.72401434, 0.76491228]),
#    'AUC': array([0.54330484, 0.58991465]),
#    'Entropy-Loss': array([13.87680655, 12.07462389]),
#    'TP': array([101., 109.]),
#    'TN': array([22., 24.]),
#    'FP': array([43., 35.]),
#    'FN': array([34., 32.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 2,
#    'Particle': 4,
#    'Particle centroid': array([[30.112665043667622, 'male div/sep', 'unskilled resident'],
#           [52.841465397966005, 'female div/dep/mar', 'unskilled resident'],
#           [34.097246850091956, 'male single', 'unemp/unskilled non res']],
#          dtype=object),
#    'Accuracy': array([0.635, 0.65 ]),
#    'Precision': array([0.76923077, 0.77941176]),
#    'Recall': array([0.6993007, 0.7260274]),
#    'F1 score': array([0.73260073, 0.75177305]),
#    'AUC': array([0.58649245, 0.58523592]),
#    'Entropy-Loss': array([13.15593349, 12.61527869]),
#    'TP': array([100., 106.]),
#    'TN': array([27., 24.]),
#    'FP': array([30., 30.]),
#    'FN': array([43., 40.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 2,
#    'Particle': 5,
#    'Particle centroid': array([[21.18477718263234, 'male mar/wid', 'unskilled resident'],
#           [19.18477718263234, 'female div/dep/mar', 'unskilled resident'],
#           [70.75785428402932, 'male mar/wid', 'unskilled resident']],
#          dtype=object),
#    'Accuracy': array([0.7  , 0.615]),
#    'Precision': array([0.76811594, 0.72868217]),
#    'Recall': array([0.79104478, 0.69117647]),
#    'F1 score': array([0.77941176, 0.70943396]),
#    'AUC': array([0.65309815, 0.57215074]),
#    'Entropy-Loss': array([10.81309602, 13.87680655]),
#    'TP': array([106.,  94.]),
#    'TN': array([34., 29.]),
#    'FP': array([32., 35.]),
#    'FN': array([28., 42.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 2,
#    'num_violated_clusters': 1,
#    'num_violating_records_before_adjusting': 13,
#    'num_retained_records': 40,
#    'num_excess_records': 947,
#    'num_fixed_clusters': 1,
#    'num_used_excess': 7,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 2,
#    'Particle': 6,
# ...
#    'Particle': 5,
#    'Particle centroid': array([[36.83995919264568, 'male mar/wid', 'unemp/unskilled non res'],
#           [34.83995919264568, 'female div/dep/mar', 'unskilled resident'],
#           [57.29794463439225, 'male single', 'unskilled resident']],
#          dtype=object),
#    'Accuracy': array([0.685, 0.705]),
#    'Precision': array([0.78873239, 0.77083333]),
#    'Recall': array([0.77241379, 0.81021898]),
#    'F1 score': array([0.7804878 , 0.79003559]),
#    'AUC': array([0.61347962, 0.64320473]),
#    'Entropy-Loss': array([11.35375082, 10.63287775]),
#    'TP': array([112., 111.]),
#    'TN': array([25., 30.]),
#    'FP': array([30., 33.]),
#    'FN': array([33., 26.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 19,
#    'Particle': 6,
#    'Particle centroid': array([[49.822460297488675, 'female div/dep/mar', 'skilled'],
#           [38.854883164626465, 'male mar/wid', 'skilled'],
#           [41.334840057546714, 'male single', 'unemp/unskilled non res']],
#          dtype=object),
#    'Accuracy': array([0.68, 0.72]),
#    'Precision': array([0.76978417, 0.77483444]),
#    'Recall': array([0.76978417, 0.84172662]),
#    'F1 score': array([0.76978417, 0.80689655]),
#    'AUC': array([0.622597  , 0.64217478]),
#    'Entropy-Loss': array([11.53396908, 10.09222295]),
#    'TP': array([107., 117.]),
#    'TN': array([29., 27.]),
#    'FP': array([32., 34.]),
#    'FN': array([32., 22.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 19,
#    'Particle': 7,
#    'Particle centroid': array([[41.393019283678164, 'male div/sep', 'high qualif/self emp/mgmt'],
#           [46.90390677216702, 'female div/dep/mar', 'skilled'],
#           [45.18211270965587, 'male div/sep', 'high qualif/self emp/mgmt']],
#          dtype=object),
#    'Accuracy': array([0.715, 0.645]),
#    'Precision': array([0.82978723, 0.73282443]),
#    'Recall': array([0.78      , 0.72727273]),
#    'F1 score': array([0.80412371, 0.73003802]),
#    'AUC': array([0.65      , 0.60628342]),
#    'Entropy-Loss': array([10.27244122, 12.79549695]),
#    'TP': array([117.,  96.]),
#    'TN': array([26., 33.]),
#    'FP': array([24., 35.]),
#    'FN': array([33., 36.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 19,
#    'Particle': 8,
#    'Particle centroid': array([[40.01701280957859, 'male single', 'high qualif/self emp/mgmt'],
#           [34.76925046235448, 'male div/sep', 'unemp/unskilled non res'],
#           [45.651156854195456, 'female div/dep/mar', 'skilled']],
#          dtype=object),
#    'Accuracy': array([0.665, 0.73 ]),
#    'Precision': array([0.76153846, 0.77852349]),
#    'Recall': array([0.73333333, 0.84671533]),
#    'F1 score': array([0.74716981, 0.81118881]),
#    'AUC': array([0.62820513, 0.6614529 ]),
#    'Entropy-Loss': array([12.07462389,  9.73178642]),
#    'TP': array([ 99., 116.]),
#    'TN': array([34., 30.]),
#    'FP': array([31., 33.]),
#    'FN': array([36., 21.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 19,
#    'Particle': 9,
#    'Particle centroid': array([[51.73817569855685, 'male div/sep', 'high qualif/self emp/mgmt'],
#           [44.64996606040241, 'male single', 'high qualif/self emp/mgmt'],
#           [48.957316838512575, 'male single', 'unskilled resident']],
#          dtype=object),
#    'Accuracy': array([0.695, 0.685]),
#    'Precision': array([0.76691729, 0.75886525]),
#    'Recall': array([0.77272727, 0.78676471]),
#    'F1 score': array([0.76981132, 0.77256318]),
#    'AUC': array([0.65842246, 0.62775735]),
#    'Entropy-Loss': array([10.99331428, 11.35375082]),
#    'TP': array([102., 107.]),
#    'TN': array([37., 30.]),
#    'FP': array([31., 34.]),
#    'FN': array([30., 29.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 19,
#    'Particle': 10,
#    'Particle centroid': array([[46.47437720559704, 'male mar/wid', 'skilled'],
#           [39.31921424735961, 'male mar/wid', 'high qualif/self emp/mgmt'],
#           [51.12561113640656, 'male div/sep', 'unemp/unskilled non res']],
#          dtype=object),
#    'Accuracy': array([0.655, 0.67 ]),
#    'Precision': array([0.74482759, 0.72142857]),
#    'Recall': array([0.77142857, 0.7890625 ]),
#    'F1 score': array([0.75789474, 0.75373134]),
#    'AUC': array([0.57738095, 0.62369792]),
#    'Entropy-Loss': array([12.43506042, 11.89440562]),
#    'TP': array([108., 101.]),
#    'TN': array([23., 33.]),
#    'FP': array([37., 39.]),
#    'FN': array([32., 27.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 19,
#    'Particle': 11,
#    'Particle centroid': array([[48.746187100438185, 'male mar/wid', 'unemp/unskilled non res'],
#           [44.28320176331959, 'male single', 'skilled'],
#           [47.5202014229447, 'male mar/wid', 'unskilled resident']],
#          dtype=object),
#    'Accuracy': array([0.705, 0.64 ]),
#    'Precision': array([0.8030303 , 0.78225806]),
#    'Recall': array([0.76258993, 0.68309859]),
#    'F1 score': array([0.78228782, 0.72932331]),
#    'AUC': array([0.66818021, 0.60879068]),
#    'Entropy-Loss': array([10.63287775, 12.97571522]),
#    'TP': array([106.,  97.]),
#    'TN': array([35., 31.]),
#    'FP': array([26., 27.]),
#    'FN': array([33., 45.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 19,
#    'Particle': 12,
#    'Particle centroid': array([[49.00560976818261, 'male single', 'unskilled resident'],
#           [45.71984935612526, 'male single', 'unemp/unskilled non res'],
#           [50.370659887825774, 'male single', 'unskilled resident']],
#          dtype=object),
#    'Accuracy': array([0.72, 0.71]),
#    'Precision': array([0.77622378, 0.77372263]),
#    'Recall': array([0.82222222, 0.79699248]),
#    'F1 score': array([0.79856115, 0.78518519]),
#    'AUC': array([0.66495726, 0.66715296]),
#    'Entropy-Loss': array([10.09222295, 10.45265948]),
#    'TP': array([111., 106.]),
#    'TN': array([33., 36.]),
#    'FP': array([32., 31.]),
#    'FN': array([24., 27.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 19,
#    'Particle': 13,
#    'Particle centroid': array([[45.77272967831361, 'female div/dep/mar', 'skilled'],
#           [34.401191454779635, 'male div/sep', 'skilled'],
#           [41.15968783150643, 'female div/dep/mar', 'unskilled resident']],
#          dtype=object),
#    'Accuracy': array([0.715, 0.625]),
#    'Precision': array([0.81818182, 0.7080292 ]),
#    'Recall': array([0.76595745, 0.73484848]),
#    'F1 score': array([0.79120879, 0.72118959]),
#    'AUC': array([0.67958889, 0.5733066 ]),
#    'Entropy-Loss': array([10.27244122, 13.51637002]),
#    'TP': array([108.,  97.]),
#    'TN': array([35., 28.]),
#    'FP': array([24., 40.]),
#    'FN': array([33., 35.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 19,
#    'Particle': 14,
#    'Particle centroid': array([[42.91944749660544, 'female div/dep/mar', 'skilled'],
#           [41.1923071828133, 'male mar/wid', 'unemp/unskilled non res'],
#           [47.93432031047424, 'female div/dep/mar',
#            'high qualif/self emp/mgmt']], dtype=object),
#    'Accuracy': array([0.705, 0.74 ]),
#    'Precision': array([0.81118881, 0.83969466]),
#    'Recall': array([0.78378378, 0.78014184]),
#    'F1 score': array([0.79725086, 0.80882353]),
#    'AUC': array([0.63227651, 0.71210482]),
#    'Entropy-Loss': array([10.63287775,  9.37134988]),
#    'TP': array([116., 110.]),
#    'TN': array([25., 38.]),
#    'FP': array([27., 21.]),
#    'FN': array([32., 31.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 19,
#    'Particle': 15,
#    'Particle centroid': array([[43.614403659414194, 'male div/sep', 'high qualif/self emp/mgmt'],
#           [41.614403659414194, 'male single', 'skilled'],
#           [51.03600914853548, 'female div/dep/mar',
#            'high qualif/self emp/mgmt']], dtype=object),
#    'Accuracy': array([0.685, 0.705]),
#    'Precision': array([0.76056338, 0.76027397]),
#    'Recall': array([0.78832117, 0.82222222]),
#    'F1 score': array([0.77419355, 0.79003559]),
#    'AUC': array([0.62431931, 0.64188034]),
#    'Entropy-Loss': array([11.35375082, 10.63287775]),
#    'TP': array([108., 111.]),
#    'TN': array([29., 30.]),
#    'FP': array([34., 35.]),
#    'FN': array([29., 24.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 19,
#    'Particle': 16,
#    'Particle centroid': array([[49.97634706368845, 'male mar/wid', 'high qualif/self emp/mgmt'],
#           [51.28861569463284, 'female div/dep/mar',
#            'high qualif/self emp/mgmt'],
#           [58.16335578721854, 'male div/sep', 'high qualif/self emp/mgmt']],
#          dtype=object),
#    'Accuracy': array([0.71 , 0.695]),
#    'Precision': array([0.79166667, 0.74829932]),
#    'Recall': array([0.8028169 , 0.82089552]),
#    'F1 score': array([0.7972028 , 0.78291815]),
#    'AUC': array([0.64278776, 0.63014473]),
#    'Entropy-Loss': array([10.45265948, 10.99331428]),
#    'TP': array([114., 110.]),
#    'TN': array([28., 29.]),
#    'FP': array([30., 37.]),
#    'FN': array([28., 24.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 19,
#    'Particle': 17,
#    'Particle centroid': array([[48.357302262633766, 'male div/sep', 'unskilled resident'],
#           [47.72961117647912, 'male single', 'unemp/unskilled non res'],
#           [47.34042129967044, 'male mar/wid', 'unemp/unskilled non res']],
#          dtype=object),
#    'Accuracy': array([0.695, 0.605]),
#    'Precision': array([0.7414966 , 0.74418605]),
#    'Recall': array([0.82575758, 0.67605634]),
#    'F1 score': array([0.78136201, 0.70848708]),
#    'AUC': array([0.63346702, 0.55354541]),
#    'Entropy-Loss': array([10.99331428, 14.23724309]),
#    'TP': array([109.,  96.]),
#    'TN': array([30., 25.]),
#    'FP': array([38., 33.]),
#    'FN': array([23., 46.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 2,
#    'num_violated_clusters': 1,
#    'num_violating_records_before_adjusting': 19,
#    'num_retained_records': 40,
#    'num_excess_records': 941,
#    'num_fixed_clusters': 1,
#    'num_used_excess': 1,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 19,
#    'Particle': 18,
#    'Particle centroid': array([[43.95765236950221, 'male mar/wid', 'unemp/unskilled non res'],
#           [42.726600741885335, 'male mar/wid', 'skilled'],
#           [53.047553482330216, 'male single', 'unskilled resident']],
#          dtype=object),
#    'Accuracy': array([0.7 , 0.68]),
#    'Precision': array([0.75362319, 0.77692308]),
#    'Recall': array([0.8       , 0.74264706]),
#    'F1 score': array([0.7761194, 0.7593985]),
#    'AUC': array([0.65714286, 0.64476103]),
#    'Entropy-Loss': array([10.81309602, 11.53396908]),
#    'TP': array([104., 101.]),
#    'TN': array([36., 35.]),
#    'FP': array([34., 29.]),
#    'FN': array([26., 35.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0},
#   {'ML model': 'DT',
#    'Iteration': 19,
#    'Particle': 19,
#    'Particle centroid': array([[41.263417200080426, 'male div/sep', 'skilled'],
#           [39.263417200080426, 'male div/sep', 'unskilled resident'],
#           [45.15854300020107, 'male single', 'high qualif/self emp/mgmt']],
#          dtype=object),
#    'Accuracy': array([0.655, 0.66 ]),
#    'Precision': array([0.79527559, 0.78571429]),
#    'Recall': array([0.70138889, 0.70714286]),
#    'F1 score': array([0.74538745, 0.7443609 ]),
#    'AUC': array([0.61855159, 0.62857143]),
#    'Entropy-Loss': array([12.43506042, 12.25484215]),
#    'TP': array([101.,  99.]),
#    'TN': array([30., 33.]),
#    'FP': array([26., 27.]),
#    'FN': array([43., 41.]),
#    'num_clusters': 3,
#    'num_valid_clusters': 3,
#    'num_violated_clusters': 0,
#    'num_violating_records_before_adjusting': 0,
#    'num_retained_records': 60,
#    'num_excess_records': 940,
#    'num_fixed_clusters': 0,
#    'num_used_excess': 0,
#    'num_remaining_excess': 940,
#    'num_unfixed_clusters': 0,
#    'num_total_violating_records_after_adjusting': 0}]]

# %%
# save the results to a file
results_df = pd.DataFrame(results)
filedirectory = '/Users/yusiwei/Library/CloudStorage/OneDrive-Personal/research/Fourth Year Paper/Experiments/2nd experiments/Experiment results/V2/Iteration Tracking Info'
filename = f"DT_Anonymization_16.csv"
filename = os.path.join(filedirectory, filename)
results_df.to_csv(filename, index=False)
